# %% [markdown]
# CAPSTONE PROJECT: INCREASING REAL ESTATE MANAGEMENT PROFITS: HARNESSING DATA ANALYTICS

# %% [markdown]
# # Extracting Watershed Database Project

# %% [markdown]
# Watershed's intern put together a couple of sources of information that will be useful for your project. These three types of information are contained in the capstone database:
# 1. the current monthly rent Watershed charges for all of their client’s 244 properties, as well as the property type and geographic location of those properties.
# 2. some general information about examples of short-term rental properties.  This information can be used to get a sense of what kind of nightly rental price Watershed’s client’s properties *could* be listed for, if they were converted to short-term rentals.
# 3. records about when those short-term rental properties were rented out, so that you can calculate their occupancy rates.

# %% [markdown]
# Your job is to determine how the database is organized so that you can retrieve all of the available information about Watershed’s client’s 244 properties, as well as the corresponding short-term rental information for comparable properties in the same location and of the same type.
# 1. Start by determining what tables the database contains, and what fields are included in each table.
# 2. Then, we recommend that you make at least a rough relational schema of how the database is organized, so that you know what fields you can use to join tables.
# 3. Next, make a list of the columns of data you want to retrieve in your final output.
# 4. Finally, write your query to retrieve the desired data from the database.

# %% [markdown]
# ### Load and connect to the database

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@localhost/capstone 
# %sql USE capstone
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 0 rows affected.
# []

# %% [markdown]
# ### Query1
#
# Extracting Table for watershed_property_info

# %%
# %sql select * from watershed_property_info Limit 244;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# [('W1', 'L9531', 'R6', 1060),
#  ('W10', 'L9533', 'R6', 1200),
#  ('W100', 'L1944', 'R2', 3300),
#  ('W101', 'L15257', 'R2', 1400),
#  ('W102', 'L15257', 'R6', 2000),
#  ('W103', 'L15257', 'R10', 1600),
#  ('W104', 'L15257', 'R14', 2800),
#  ('W105', 'L15260', 'R2', 1100),
#  ('W106', 'L15260', 'R6', 1900),
#  ('W107', 'L15260', 'R10', 1800),
#  ('W108', 'L15260', 'R14', 3200),
#  ('W109', 'L15264', 'R2', 1000),
#  ('W11', 'L9533', 'R10', 1000),
#  ('W110', 'L15264', 'R6', 1300),
#  ('W111', 'L15264', 'R10', 1200),
#  ('W112', 'L15264', 'R14', 1600),
#  ('W113', 'L15278', 'R2', 800),
#  ('W114', 'L15278', 'R6', 1200),
#  ('W115', 'L15278', 'R10', 900),
#  ('W116', 'L15278', 'R14', 1100),
#  ('W117', 'L15280', 'R2', 1000),
#  ('W118', 'L15280', 'R6', 1400),
#  ('W119', 'L15280', 'R10', 1500),
#  ('W12', 'L9533', 'R14', 1300),
#  ('W120', 'L15280', 'R14', 1600),
#  ('W121', 'L463', 'R2', 600),
#  ('W122', 'L463', 'R6', 800),
#  ('W123', 'L463', 'R10', 700),
#  ('W124', 'L463', 'R14', 1000),
#  ('W125', 'L464', 'R2', 700),
#  ('W126', 'L464', 'R6', 900),
#  ('W127', 'L464', 'R10', 1000),
#  ('W128', 'L464', 'R14', 1200),
#  ('W129', 'L2314', 'R2', 1200),
#  ('W13', 'L9534', 'R6', 920),
#  ('W130', 'L2314', 'R6', 1300),
#  ('W131', 'L2314', 'R10', 1100),
#  ('W132', 'L2314', 'R14', 1200),
#  ('W133', 'L2318', 'R2', 1300),
#  ('W134', 'L2318', 'R6', 1700),
#  ('W135', 'L2318', 'R10', 1200),
#  ('W136', 'L2318', 'R14', 1900),
#  ('W137', 'L2323', 'R2', 1000),
#  ('W138', 'L2323', 'R6', 1500),
#  ('W139', 'L2323', 'R10', 1300),
#  ('W14', 'L9534', 'R10', 850),
#  ('W140', 'L2323', 'R14', 1800),
#  ('W141', 'L2325', 'R2', 1100),
#  ('W142', 'L2325', 'R6', 1400),
#  ('W143', 'L2325', 'R10', 1300),
#  ('W144', 'L2325', 'R14', 1900),
#  ('W145', 'L2338', 'R2', 900),
#  ('W146', 'L2338', 'R6', 1400),
#  ('W147', 'L2338', 'R10', 1400),
#  ('W148', 'L2338', 'R14', 1700),
#  ('W149', 'L3244', 'R2', 800),
#  ('W15', 'L9534', 'R14', 900),
#  ('W150', 'L3244', 'R6', 1300),
#  ('W151', 'L3244', 'R10', 1400),
#  ('W152', 'L3244', 'R14', 1900),
#  ('W153', 'L3256', 'R2', 1700),
#  ('W154', 'L3256', 'R6', 2400),
#  ('W155', 'L3256', 'R10', 2100),
#  ('W156', 'L3256', 'R14', 3200),
#  ('W157', 'L3261', 'R2', 1300),
#  ('W158', 'L3261', 'R6', 1700),
#  ('W159', 'L3261', 'R10', 1400),
#  ('W16', 'L9534', 'R2', 750),
#  ('W160', 'L3261', 'R14', 1900),
#  ('W161', 'L3262', 'R2', 1600),
#  ('W162', 'L3262', 'R6', 2200),
#  ('W163', 'L3262', 'R10', 1500),
#  ('W164', 'L3262', 'R14', 2400),
#  ('W165', 'L3264', 'R2', 1600),
#  ('W166', 'L3264', 'R6', 1900),
#  ('W167', 'L3264', 'R10', 1400),
#  ('W168', 'L3264', 'R14', 2000),
#  ('W169', 'L10126', 'R2', 1000),
#  ('W17', 'L4761', 'R6', 2500),
#  ('W170', 'L10126', 'R6', 1400),
#  ('W171', 'L10126', 'R10', 1300),
#  ('W172', 'L10126', 'R14', 1800),
#  ('W173', 'L10130', 'R2', 700),
#  ('W174', 'L10130', 'R6', 900),
#  ('W175', 'L10130', 'R10', 1000),
#  ('W176', 'L10130', 'R14', 1200),
#  ('W177', 'L10133', 'R2', 700),
#  ('W178', 'L10133', 'R6', 1000),
#  ('W179', 'L10133', 'R10', 800),
#  ('W18', 'L4761', 'R10', 2500),
#  ('W180', 'L10133', 'R14', 900),
#  ('W181', 'L10136', 'R2', 700),
#  ('W182', 'L10136', 'R6', 1000),
#  ('W183', 'L10136', 'R10', 900),
#  ('W184', 'L10136', 'R14', 1200),
#  ('W185', 'L1882', 'R2', 1100),
#  ('W186', 'L1882', 'R6', 1400),
#  ('W187', 'L1882', 'R10', 1300),
#  ('W188', 'L1882', 'R14', 1900),
#  ('W189', 'L1883', 'R2', 900),
#  ('W19', 'L4761', 'R14', 2800),
#  ('W190', 'L1883', 'R6', 1100),
#  ('W191', 'L1883', 'R10', 1300),
#  ('W192', 'L1883', 'R14', 1600),
#  ('W193', 'L1887', 'R2', 1400),
#  ('W194', 'L1887', 'R6', 2000),
#  ('W195', 'L1887', 'R10', 1700),
#  ('W196', 'L1887', 'R14', 2500),
#  ('W197', 'L1902', 'R2', 1800),
#  ('W198', 'L1902', 'R6', 2600),
#  ('W199', 'L1902', 'R10', 2500),
#  ('W2', 'L9531', 'R10', 1500),
#  ('W20', 'L4761', 'R2', 1700),
#  ('W200', 'L1902', 'R14', 3600),
#  ('W201', 'L1916', 'R2', 1200),
#  ('W202', 'L1916', 'R6', 1600),
#  ('W203', 'L1916', 'R10', 1000),
#  ('W204', 'L1916', 'R14', 1500),
#  ('W205', 'L12252', 'R2', 750),
#  ('W206', 'L12252', 'R6', 1040),
#  ('W207', 'L12252', 'R10', 900),
#  ('W208', 'L12252', 'R14', 1400),
#  ('W209', 'L12260', 'R2', 825),
#  ('W21', 'L4765', 'R6', 2700),
#  ('W210', 'L12260', 'R6', 1300),
#  ('W211', 'L12260', 'R10', 1000),
#  ('W212', 'L12260', 'R14', 1480),
#  ('W213', 'L12264', 'R2', 650),
#  ('W214', 'L12264', 'R6', 920),
#  ('W215', 'L12264', 'R10', 880),
#  ('W216', 'L12264', 'R14', 1200),
#  ('W217', 'L16888', 'R2', 1000),
#  ('W218', 'L16888', 'R6', 1200),
#  ('W219', 'L16888', 'R10', 1400),
#  ('W22', 'L4765', 'R10', 2700),
#  ('W220', 'L16888', 'R14', 1600),
#  ('W221', 'L16887', 'R2', 1105),
#  ('W222', 'L16887', 'R6', 1665),
#  ('W223', 'L16887', 'R10', 1175),
#  ('W224', 'L16887', 'R14', 1725),
#  ('W225', 'L16898', 'R2', 709),
#  ('W226', 'L16898', 'R6', 869),
#  ('W227', 'L16898', 'R10', 925),
#  ('W228', 'L16898', 'R14', 1350),
#  ('W229', 'L16890', 'R2', 900),
#  ('W23', 'L4765', 'R14', 3200),
#  ('W230', 'L16890', 'R6', 1325),
#  ('W231', 'L16890', 'R10', 975),
#  ('W232', 'L16890', 'R14', 1550),
#  ('W233', 'L14416', 'R2', 1165),
#  ('W234', 'L14416', 'R6', 1625),
#  ('W235', 'L14416', 'R10', 1400),
#  ('W236', 'L14416', 'R14', 1995),
#  ('W237', 'L14418', 'R2', 760),
#  ('W238', 'L14418', 'R6', 965),
#  ('W239', 'L14418', 'R10', 1185),
#  ('W24', 'L4765', 'R2', 1700),
#  ('W240', 'L14418', 'R14', 1340),
#  ('W241', 'L14419', 'R2', 1150),
#  ('W242', 'L14419', 'R6', 2000),
#  ('W243', 'L14419', 'R10', 1600),
#  ('W244', 'L14419', 'R14', 2150),
#  ('W25', 'L4770', 'R2', 1600),
#  ('W26', 'L4770', 'R6', 2100),
#  ('W27', 'L4770', 'R10', 1200),
#  ('W28', 'L4770', 'R14', 2100),
#  ('W29', 'L4794', 'R6', 2500),
#  ('W3', 'L9531', 'R14', 2000),
#  ('W30', 'L4794', 'R10', 2500),
#  ('W31', 'L4794', 'R14', 2750),
#  ('W32', 'L4794', 'R2', 1800),
#  ('W33', 'L4804', 'R6', 3000),
#  ('W34', 'L4804', 'R10', 2000),
#  ('W35', 'L4804', 'R14', 2950),
#  ('W36', 'L4804', 'R2', 1700),
#  ('W37', 'L11419', 'R2', 3000),
#  ('W38', 'L11419', 'R6', 3200),
#  ('W39', 'L11421', 'R6', 4500),
#  ('W4', 'L9531', 'R2', 800),
#  ('W40', 'L11421', 'R10', 4500),
#  ('W41', 'L11421', 'R14', 5500),
#  ('W42', 'L11421', 'R2', 3500),
#  ('W43', 'L11427', 'R6', 4000),
#  ('W44', 'L11427', 'R2', 3000),
#  ('W45', 'L11431', 'R6', 5600),
#  ('W46', 'L11431', 'R10', 3200),
#  ('W47', 'L11431', 'R14', 3500),
#  ('W48', 'L11431', 'R2', 3400),
#  ('W49', 'L11434', 'R6', 4200),
#  ('W5', 'L9532', 'R6', 1100),
#  ('W50', 'L11434', 'R10', 3000),
#  ('W51', 'L11434', 'R14', 3900),
#  ('W52', 'L11434', 'R2', 3600),
#  ('W53', 'L11480', 'R6', 3500),
#  ('W54', 'L11480', 'R10', 2500),
#  ('W55', 'L11480', 'R14', 3000),
#  ('W56', 'L11480', 'R2', 3000),
#  ('W57', 'L11495', 'R6', 3900),
#  ('W58', 'L11495', 'R10', 2800),
#  ('W59', 'L11495', 'R14', 3500),
#  ('W6', 'L9532', 'R10', 900),
#  ('W60', 'L11495', 'R2', 2600),
#  ('W61', 'L1734', 'R6', 2695),
#  ('W62', 'L1734', 'R10', 3000),
#  ('W63', 'L1734', 'R14', 4000),
#  ('W64', 'L1734', 'R2', 2295),
#  ('W65', 'L1735', 'R6', 3000),
#  ('W66', 'L1735', 'R10', 3300),
#  ('W67', 'L1735', 'R14', 4500),
#  ('W68', 'L1735', 'R2', 2700),
#  ('W69', 'L1736', 'R2', 2700),
#  ('W7', 'L9532', 'R14', 1100),
#  ('W70', 'L1736', 'R6', 3000),
#  ('W71', 'L1736', 'R10', 4500),
#  ('W72', 'L1736', 'R14', 4900),
#  ('W73', 'L1737', 'R6', 3300),
#  ('W74', 'L1737', 'R10', 4500),
#  ('W75', 'L1737', 'R14', 4200),
#  ('W76', 'L1737', 'R2', 2500),
#  ('W77', 'L1738', 'R2', 2500),
#  ('W78', 'L1738', 'R6', 3300),
#  ('W79', 'L1738', 'R10', 4500),
#  ('W8', 'L9532', 'R2', 500),
#  ('W80', 'L1738', 'R14', 4200),
#  ('W81', 'L1940', 'R6', 3600),
#  ('W82', 'L1940', 'R10', 4000),
#  ('W83', 'L1940', 'R14', 5500),
#  ('W84', 'L1940', 'R2', 3000),
#  ('W85', 'L1941', 'R6', 4000),
#  ('W86', 'L1941', 'R10', 4000),
#  ('W87', 'L1941', 'R14', 5000),
#  ('W88', 'L1941', 'R2', 3200),
#  ('W89', 'L1942', 'R6', 3500),
#  ('W9', 'L9533', 'R2', 965),
#  ('W90', 'L1942', 'R10', 3200),
#  ('W91', 'L1942', 'R14', 3500),
#  ('W92', 'L1942', 'R2', 3000),
#  ('W93', 'L1943', 'R2', 2600),
#  ('W94', 'L1943', 'R6', 4000),
#  ('W95', 'L1943', 'R10', 4000),
#  ('W96', 'L1943', 'R14', 5100),
#  ('W97', 'L1944', 'R6', 5600),
#  ('W98', 'L1944', 'R10', 5000),
#  ('W99', 'L1944', 'R14', 6000)]

# %% [markdown]
# ### Query2
#
# Extracting Table for st_rental_prices

# %%
# %sql SELECT * FROM st_rental_prices Limit 244;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# [('L10126', 'R1', 83, 273, 192),
#  ('L10126', 'R10', 155, 494, 257),
#  ('L10126', 'R11', 82, 411, 242),
#  ('L10126', 'R12', 119, 366, 229),
#  ('L10126', 'R13', 137, 416, 375),
#  ('L10126', 'R14', 151, 391, 286),
#  ('L10126', 'R15', 116, 312, 172),
#  ('L10126', 'R16', 126, 343, 258),
#  ('L10126', 'R2', 91, 342, 229),
#  ('L10126', 'R3', 41, 242, 117),
#  ('L10126', 'R4', 83, 263, 193),
#  ('L10126', 'R5', 153, 340, 218),
#  ('L10126', 'R6', 168, 392, 322),
#  ('L10126', 'R7', 140, 401, 350),
#  ('L10126', 'R8', 129, 409, 230),
#  ('L10126', 'R9', 111, 371, 155),
#  ('L10130', 'R1', 62, 188, 129),
#  ('L10130', 'R10', 190, 462, 221),
#  ('L10130', 'R11', 136, 393, 260),
#  ('L10130', 'R12', 158, 415, 313),
#  ('L10130', 'R13', 146, 440, 233),
#  ('L10130', 'R14', 205, 411, 316),
#  ('L10130', 'R15', 103, 309, 169),
#  ('L10130', 'R16', 186, 402, 317),
#  ('L10130', 'R2', 99, 265, 180),
#  ('L10130', 'R3', 50, 216, 156),
#  ('L10130', 'R4', 90, 294, 202),
#  ('L10130', 'R5', 96, 264, 123),
#  ('L10130', 'R6', 154, 286, 230),
#  ('L10130', 'R7', 81, 249, 147),
#  ('L10130', 'R8', 118, 322, 180),
#  ('L10130', 'R9', 158, 415, 226),
#  ('L10133', 'R1', 120, 304, 156),
#  ('L10133', 'R10', 186, 465, 325),
#  ('L10133', 'R11', 124, 369, 343),
#  ('L10133', 'R12', 143, 501, 381),
#  ('L10133', 'R13', 131, 387, 340),
#  ('L10133', 'R14', 209, 358, 256),
#  ('L10133', 'R15', 190, 339, 223),
#  ('L10133', 'R16', 190, 401, 342),
#  ('L10133', 'R2', 192, 313, 245),
#  ('L10133', 'R3', 175, 305, 258),
#  ('L10133', 'R4', 148, 357, 293),
#  ('L10133', 'R5', 160, 348, 272),
#  ('L10133', 'R6', 192, 357, 266),
#  ('L10133', 'R7', 91, 279, 148),
#  ('L10133', 'R8', 175, 430, 254),
#  ('L10133', 'R9', 124, 345, 237),
#  ('L10136', 'R1', 35, 161, 101),
#  ('L10136', 'R10', 86, 488, 418),
#  ('L10136', 'R11', 66, 261, 104),
#  ('L10136', 'R12', 72, 479, 245),
#  ('L10136', 'R13', 59, 430, 176),
#  ('L10136', 'R14', 83, 556, 219),
#  ('L10136', 'R15', 59, 324, 240),
#  ('L10136', 'R16', 75, 328, 242),
#  ('L10136', 'R2', 42, 252, 184),
#  ('L10136', 'R3', 35, 150, 113),
#  ('L10136', 'R4', 32, 226, 103),
#  ('L10136', 'R5', 85, 439, 180),
#  ('L10136', 'R6', 94, 531, 427),
#  ('L10136', 'R7', 52, 305, 244),
#  ('L10136', 'R8', 72, 426, 179),
#  ('L10136', 'R9', 54, 325, 230),
#  ('L11419', 'R1', 54, 374, 176),
#  ('L11419', 'R2', 87, 512, 337),
#  ('L11419', 'R3', 62, 306, 192),
#  ('L11419', 'R4', 73, 439, 414),
#  ('L11419', 'R5', 140, 358, 317),
#  ('L11419', 'R6', 154, 480, 154),
#  ('L11419', 'R7', 103, 332, 178),
#  ('L11419', 'R8', 118, 358, 294),
#  ('L11421', 'R1', 137, 693, 427),
#  ('L11421', 'R10', 103, 807, 200),
#  ('L11421', 'R11', 61, 565, 119),
#  ('L11421', 'R12', 94, 461, 403),
#  ('L11421', 'R13', 125, 553, 523),
#  ('L11421', 'R14', 200, 770, 428),
#  ('L11421', 'R15', 125, 475, 431),
#  ('L11421', 'R16', 154, 704, 251),
#  ('L11421', 'R2', 151, 890, 576),
#  ('L11421', 'R3', 137, 661, 542),
#  ('L11421', 'R4', 116, 752, 231),
#  ('L11421', 'R5', 171, 780, 241),
#  ('L11421', 'R6', 273, 853, 432),
#  ('L11421', 'R7', 144, 571, 172),
#  ('L11421', 'R8', 210, 684, 381),
#  ('L11421', 'R9', 79, 483, 243),
#  ('L11427', 'R1', 99, 436, 318),
#  ('L11427', 'R2', 109, 640, 288),
#  ('L11427', 'R3', 84, 375, 190),
#  ('L11427', 'R4', 99, 436, 370),
#  ('L11427', 'R5', 168, 546, 484),
#  ('L11427', 'R6', 218, 681, 560),
#  ('L11427', 'R7', 156, 418, 175),
#  ('L11427', 'R8', 198, 556, 523),
#  ('L11431', 'R1', 82, 498, 467),
#  ('L11431', 'R10', 165, 1296, 420),
#  ('L11431', 'R11', 97, 660, 371),
#  ('L11431', 'R12', 127, 991, 750),
#  ('L11431', 'R13', 179, 648, 437),
#  ('L11431', 'R14', 268, 1032, 593),
#  ('L11431', 'R15', 223, 714, 548),
#  ('L11431', 'R16', 206, 697, 564),
#  ('L11431', 'R2', 106, 624, 436),
#  ('L11431', 'R3', 62, 359, 205),
#  ('L11431', 'R4', 96, 380, 241),
#  ('L11431', 'R5', 131, 453, 294),
#  ('L11431', 'R6', 196, 612, 373),
#  ('L11431', 'R7', 151, 442, 391),
#  ('L11431', 'R8', 163, 469, 446),
#  ('L11431', 'R9', 138, 727, 678),
#  ('L11434', 'R1', 86, 490, 216),
#  ('L11434', 'R10', 133, 1040, 621),
#  ('L11434', 'R11', 89, 522, 402),
#  ('L11434', 'R12', 121, 641, 443),
#  ('L11434', 'R13', 178, 601, 571),
#  ('L11434', 'R14', 231, 888, 535),
#  ('L11434', 'R15', 116, 471, 406),
#  ('L11434', 'R16', 178, 700, 482),
#  ('L11434', 'R2', 137, 808, 196),
#  ('L11434', 'R3', 86, 397, 286),
#  ('L11434', 'R4', 105, 778, 460),
#  ('L11434', 'R5', 191, 518, 397),
#  ('L11434', 'R6', 210, 654, 426),
#  ('L11434', 'R7', 111, 547, 359),
#  ('L11434', 'R8', 191, 576, 325),
#  ('L11434', 'R9', 95, 642, 372),
#  ('L11480', 'R1', 53, 300, 271),
#  ('L11480', 'R10', 111, 868, 471),
#  ('L11480', 'R11', 85, 664, 105),
#  ('L11480', 'R12', 101, 612, 235),
#  ('L11480', 'R13', 163, 700, 451),
#  ('L11480', 'R14', 195, 752, 620),
#  ('L11480', 'R15', 139, 609, 213),
#  ('L11480', 'R16', 163, 605, 218),
#  ('L11480', 'R2', 80, 469, 235),
#  ('L11480', 'R3', 67, 360, 332),
#  ('L11480', 'R4', 73, 366, 307),
#  ('L11480', 'R5', 119, 373, 255),
#  ('L11480', 'R6', 155, 483, 294),
#  ('L11480', 'R7', 82, 292, 196),
#  ('L11480', 'R8', 141, 361, 340),
#  ('L11480', 'R9', 79, 561, 501),
#  ('L11495', 'R1', 63, 277, 98),
#  ('L11495', 'R10', 102, 799, 355),
#  ('L11495', 'R11', 73, 393, 206),
#  ('L11495', 'R12', 85, 506, 340),
#  ('L11495', 'R13', 171, 624, 257),
#  ('L11495', 'R14', 188, 724, 436),
#  ('L11495', 'R15', 118, 463, 400),
#  ('L11495', 'R16', 145, 748, 610),
#  ('L11495', 'R2', 69, 406, 250),
#  ('L11495', 'R3', 46, 231, 117),
#  ('L11495', 'R4', 53, 238, 80),
#  ('L11495', 'R5', 73, 245, 218),
#  ('L11495', 'R6', 116, 361, 284),
#  ('L11495', 'R7', 77, 258, 120),
#  ('L11495', 'R8', 89, 270, 110),
#  ('L11495', 'R9', 93, 473, 304),
#  ('L12252', 'R1', 74, 185, 127),
#  ('L12252', 'R10', 152, 300, 256),
#  ('L12252', 'R11', 101, 251, 126),
#  ('L12252', 'R12', 117, 253, 161),
#  ('L12252', 'R13', 135, 365, 281),
#  ('L12252', 'R14', 175, 368, 284),
#  ('L12252', 'R15', 159, 319, 239),
#  ('L12252', 'R16', 159, 466, 281),
#  ('L12252', 'R2', 89, 155, 124),
#  ('L12252', 'R3', 40, 126, 59),
#  ('L12252', 'R4', 74, 156, 119),
#  ('L12252', 'R5', 96, 177, 162),
#  ('L12252', 'R6', 115, 179, 156),
#  ('L12252', 'R7', 52, 164, 135),
#  ('L12252', 'R8', 105, 243, 155),
#  ('L12252', 'R9', 101, 277, 251),
#  ('L12260', 'R1', 70, 151, 88),
#  ('L12260', 'R10', 140, 288, 240),
#  ('L12260', 'R11', 88, 280, 160),
#  ('L12260', 'R12', 117, 261, 186),
#  ('L12260', 'R13', 135, 356, 239),
#  ('L12260', 'R14', 175, 310, 249),
#  ('L12260', 'R15', 92, 255, 204),
#  ('L12260', 'R16', 135, 373, 214),
#  ('L12260', 'R2', 77, 161, 128),
#  ('L12260', 'R3', 64, 137, 101),
#  ('L12260', 'R4', 59, 183, 129),
#  ('L12260', 'R5', 114, 203, 133),
#  ('L12260', 'R6', 125, 170, 139),
#  ('L12260', 'R7', 57, 170, 112),
#  ('L12260', 'R8', 104, 246, 161),
#  ('L12260', 'R9', 88, 219, 152),
#  ('L12264', 'R1', 50, 161, 100),
#  ('L12264', 'R10', 145, 333, 246),
#  ('L12264', 'R11', 91, 219, 156),
#  ('L12264', 'R12', 121, 306, 183),
#  ('L12264', 'R13', 100, 241, 208),
#  ('L12264', 'R14', 160, 310, 169),
#  ('L12264', 'R15', 100, 248, 151),
#  ('L12264', 'R16', 145, 339, 193),
#  ('L12264', 'R2', 80, 156, 107),
#  ('L12264', 'R3', 40, 105, 83),
#  ('L12264', 'R4', 67, 138, 123),
#  ('L12264', 'R5', 83, 211, 109),
#  ('L12264', 'R6', 108, 205, 147),
#  ('L12264', 'R7', 98, 235, 189),
#  ('L12264', 'R8', 83, 186, 138),
#  ('L12264', 'R9', 121, 288, 182),
#  ('L14416', 'R1', 84, 200, 159),
#  ('L14416', 'R10', 135, 287, 232),
#  ('L14416', 'R11', 90, 220, 123),
#  ('L14416', 'R12', 104, 343, 167),
#  ('L14416', 'R13', 160, 367, 320),
#  ('L14416', 'R14', 224, 331, 292),
#  ('L14416', 'R15', 187, 382, 305),
#  ('L14416', 'R16', 187, 337, 230),
#  ('L14416', 'R2', 135, 220, 180),
#  ('L14416', 'R3', 64, 174, 93),
#  ('L14416', 'R4', 104, 209, 154),
#  ('L14416', 'R5', 183, 367, 233),
#  ('L14416', 'R6', 220, 312, 260),
#  ('L14416', 'R7', 116, 246, 193),
#  ('L14416', 'R8', 169, 429, 401),
#  ('L14416', 'R9', 96, 301, 228),
#  ('L14418', 'R1', 77, 192, 105),
#  ('L14418', 'R10', 157, 320, 289),
#  ('L14418', 'R11', 75, 227, 114),
#  ('L14418', 'R12', 131, 291, 271),
#  ('L14418', 'R13', 90, 248, 112),
#  ('L14418', 'R14', 135, 347, 278),
#  ('L14418', 'R15', 123, 306, 254),
#  ('L14418', 'R16', 104, 335, 173),
#  ('L14418', 'R2', 100, 195, 169),
#  ('L14418', 'R3', 67, 148, 114),
#  ('L14418', 'R4', 83, 172, 137),
#  ('L14418', 'R5', 90, 268, 185),
#  ('L14418', 'R6', 135, 284, 189),
#  ('L14418', 'R7', 61, 170, 150),
#  ('L14418', 'R8', 123, 281, 158),
#  ('L14418', 'R9', 121, 350, 192),
#  ('L14419', 'R1', 57, 205, 82),
#  ('L14419', 'R10', 225, 406, 297),
#  ('L14419', 'R11', 173, 350, 220),
#  ('L14419', 'R12', 173, 387, 252)]

# %% [markdown]
# ### Query3
#
# Extracting Table for st_rental_dates

# %%
# %sql select * from st_rental_dates limit 244;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# [(datetime.date(2014, 1, 31), 'ST100'),
#  (datetime.date(2014, 1, 31), 'ST106'),
#  (datetime.date(2014, 1, 31), 'ST107'),
#  (datetime.date(2014, 1, 31), 'ST109'),
#  (datetime.date(2014, 1, 31), 'ST113'),
#  (datetime.date(2014, 1, 31), 'ST114'),
#  (datetime.date(2014, 1, 31), 'ST116'),
#  (datetime.date(2014, 1, 31), 'ST118'),
#  (datetime.date(2014, 1, 31), 'ST119'),
#  (datetime.date(2014, 1, 31), 'ST123'),
#  (datetime.date(2014, 1, 31), 'ST126'),
#  (datetime.date(2014, 1, 31), 'ST127'),
#  (datetime.date(2014, 1, 31), 'ST128'),
#  (datetime.date(2014, 1, 31), 'ST13'),
#  (datetime.date(2014, 1, 31), 'ST131'),
#  (datetime.date(2014, 1, 31), 'ST134'),
#  (datetime.date(2014, 1, 31), 'ST137'),
#  (datetime.date(2014, 1, 31), 'ST139'),
#  (datetime.date(2014, 1, 31), 'ST14'),
#  (datetime.date(2014, 1, 31), 'ST142'),
#  (datetime.date(2014, 1, 31), 'ST143'),
#  (datetime.date(2014, 1, 31), 'ST147'),
#  (datetime.date(2014, 1, 31), 'ST149'),
#  (datetime.date(2014, 1, 31), 'ST15'),
#  (datetime.date(2014, 1, 31), 'ST150'),
#  (datetime.date(2014, 1, 31), 'ST152'),
#  (datetime.date(2014, 1, 31), 'ST154'),
#  (datetime.date(2014, 1, 31), 'ST155'),
#  (datetime.date(2014, 1, 31), 'ST156'),
#  (datetime.date(2014, 1, 31), 'ST160'),
#  (datetime.date(2014, 1, 31), 'ST161'),
#  (datetime.date(2014, 1, 31), 'ST165'),
#  (datetime.date(2014, 1, 31), 'ST166'),
#  (datetime.date(2014, 1, 31), 'ST168'),
#  (datetime.date(2014, 1, 31), 'ST169'),
#  (datetime.date(2014, 1, 31), 'ST170'),
#  (datetime.date(2014, 1, 31), 'ST172'),
#  (datetime.date(2014, 1, 31), 'ST175'),
#  (datetime.date(2014, 1, 31), 'ST176'),
#  (datetime.date(2014, 1, 31), 'ST178'),
#  (datetime.date(2014, 1, 31), 'ST179'),
#  (datetime.date(2014, 1, 31), 'ST18'),
#  (datetime.date(2014, 1, 31), 'ST180'),
#  (datetime.date(2014, 1, 31), 'ST181'),
#  (datetime.date(2014, 1, 31), 'ST182'),
#  (datetime.date(2014, 1, 31), 'ST185'),
#  (datetime.date(2014, 1, 31), 'ST186'),
#  (datetime.date(2014, 1, 31), 'ST191'),
#  (datetime.date(2014, 1, 31), 'ST194'),
#  (datetime.date(2014, 1, 31), 'ST196'),
#  (datetime.date(2014, 1, 31), 'ST198'),
#  (datetime.date(2014, 1, 31), 'ST199'),
#  (datetime.date(2014, 1, 31), 'ST2'),
#  (datetime.date(2014, 1, 31), 'ST203'),
#  (datetime.date(2014, 1, 31), 'ST204'),
#  (datetime.date(2014, 1, 31), 'ST205'),
#  (datetime.date(2014, 1, 31), 'ST206'),
#  (datetime.date(2014, 1, 31), 'ST209'),
#  (datetime.date(2014, 1, 31), 'ST220'),
#  (datetime.date(2014, 1, 31), 'ST221'),
#  (datetime.date(2014, 1, 31), 'ST222'),
#  (datetime.date(2014, 1, 31), 'ST224'),
#  (datetime.date(2014, 1, 31), 'ST225'),
#  (datetime.date(2014, 1, 31), 'ST226'),
#  (datetime.date(2014, 1, 31), 'ST230'),
#  (datetime.date(2014, 1, 31), 'ST231'),
#  (datetime.date(2014, 1, 31), 'ST232'),
#  (datetime.date(2014, 1, 31), 'ST235'),
#  (datetime.date(2014, 1, 31), 'ST243'),
#  (datetime.date(2014, 1, 31), 'ST244'),
#  (datetime.date(2014, 1, 31), 'ST3'),
#  (datetime.date(2014, 1, 31), 'ST32'),
#  (datetime.date(2014, 1, 31), 'ST33'),
#  (datetime.date(2014, 1, 31), 'ST35'),
#  (datetime.date(2014, 1, 31), 'ST355'),
#  (datetime.date(2014, 1, 31), 'ST356'),
#  (datetime.date(2014, 1, 31), 'ST357'),
#  (datetime.date(2014, 1, 31), 'ST359'),
#  (datetime.date(2014, 1, 31), 'ST360'),
#  (datetime.date(2014, 1, 31), 'ST363'),
#  (datetime.date(2014, 1, 31), 'ST366'),
#  (datetime.date(2014, 1, 31), 'ST37'),
#  (datetime.date(2014, 1, 31), 'ST38'),
#  (datetime.date(2014, 1, 31), 'ST40'),
#  (datetime.date(2014, 1, 31), 'ST42'),
#  (datetime.date(2014, 1, 31), 'ST422'),
#  (datetime.date(2014, 1, 31), 'ST423'),
#  (datetime.date(2014, 1, 31), 'ST425'),
#  (datetime.date(2014, 1, 31), 'ST426'),
#  (datetime.date(2014, 1, 31), 'ST427'),
#  (datetime.date(2014, 1, 31), 'ST43'),
#  (datetime.date(2014, 1, 31), 'ST47'),
#  (datetime.date(2014, 1, 31), 'ST488'),
#  (datetime.date(2014, 1, 31), 'ST49'),
#  (datetime.date(2014, 1, 31), 'ST50'),
#  (datetime.date(2014, 1, 31), 'ST513'),
#  (datetime.date(2014, 1, 31), 'ST514'),
#  (datetime.date(2014, 1, 31), 'ST515'),
#  (datetime.date(2014, 1, 31), 'ST519'),
#  (datetime.date(2014, 1, 31), 'ST67'),
#  (datetime.date(2014, 1, 31), 'ST69'),
#  (datetime.date(2014, 1, 31), 'ST7'),
#  (datetime.date(2014, 1, 31), 'ST71'),
#  (datetime.date(2014, 1, 31), 'ST72'),
#  (datetime.date(2014, 1, 31), 'ST74'),
#  (datetime.date(2014, 1, 31), 'ST75'),
#  (datetime.date(2014, 1, 31), 'ST76'),
#  (datetime.date(2014, 1, 31), 'ST77'),
#  (datetime.date(2014, 1, 31), 'ST79'),
#  (datetime.date(2014, 1, 31), 'ST80'),
#  (datetime.date(2014, 1, 31), 'ST81'),
#  (datetime.date(2014, 1, 31), 'ST82'),
#  (datetime.date(2014, 1, 31), 'ST85'),
#  (datetime.date(2014, 1, 31), 'ST88'),
#  (datetime.date(2014, 1, 31), 'ST89'),
#  (datetime.date(2014, 1, 31), 'ST91'),
#  (datetime.date(2014, 1, 31), 'ST92'),
#  (datetime.date(2014, 1, 31), 'ST95'),
#  (datetime.date(2014, 1, 31), 'ST97'),
#  (datetime.date(2014, 1, 31), 'ST99'),
#  (datetime.date(2014, 2, 1), 'ST10'),
#  (datetime.date(2014, 2, 1), 'ST102'),
#  (datetime.date(2014, 2, 1), 'ST106'),
#  (datetime.date(2014, 2, 1), 'ST107'),
#  (datetime.date(2014, 2, 1), 'ST112'),
#  (datetime.date(2014, 2, 1), 'ST113'),
#  (datetime.date(2014, 2, 1), 'ST114'),
#  (datetime.date(2014, 2, 1), 'ST118'),
#  (datetime.date(2014, 2, 1), 'ST12'),
#  (datetime.date(2014, 2, 1), 'ST121'),
#  (datetime.date(2014, 2, 1), 'ST122'),
#  (datetime.date(2014, 2, 1), 'ST126'),
#  (datetime.date(2014, 2, 1), 'ST129'),
#  (datetime.date(2014, 2, 1), 'ST138'),
#  (datetime.date(2014, 2, 1), 'ST14'),
#  (datetime.date(2014, 2, 1), 'ST140'),
#  (datetime.date(2014, 2, 1), 'ST142'),
#  (datetime.date(2014, 2, 1), 'ST143'),
#  (datetime.date(2014, 2, 1), 'ST149'),
#  (datetime.date(2014, 2, 1), 'ST15'),
#  (datetime.date(2014, 2, 1), 'ST151'),
#  (datetime.date(2014, 2, 1), 'ST153'),
#  (datetime.date(2014, 2, 1), 'ST155'),
#  (datetime.date(2014, 2, 1), 'ST157'),
#  (datetime.date(2014, 2, 1), 'ST159'),
#  (datetime.date(2014, 2, 1), 'ST161'),
#  (datetime.date(2014, 2, 1), 'ST162'),
#  (datetime.date(2014, 2, 1), 'ST163'),
#  (datetime.date(2014, 2, 1), 'ST164'),
#  (datetime.date(2014, 2, 1), 'ST165'),
#  (datetime.date(2014, 2, 1), 'ST166'),
#  (datetime.date(2014, 2, 1), 'ST167'),
#  (datetime.date(2014, 2, 1), 'ST17'),
#  (datetime.date(2014, 2, 1), 'ST170'),
#  (datetime.date(2014, 2, 1), 'ST171'),
#  (datetime.date(2014, 2, 1), 'ST172'),
#  (datetime.date(2014, 2, 1), 'ST178'),
#  (datetime.date(2014, 2, 1), 'ST181'),
#  (datetime.date(2014, 2, 1), 'ST185'),
#  (datetime.date(2014, 2, 1), 'ST19'),
#  (datetime.date(2014, 2, 1), 'ST192'),
#  (datetime.date(2014, 2, 1), 'ST195'),
#  (datetime.date(2014, 2, 1), 'ST196'),
#  (datetime.date(2014, 2, 1), 'ST197'),
#  (datetime.date(2014, 2, 1), 'ST199'),
#  (datetime.date(2014, 2, 1), 'ST202'),
#  (datetime.date(2014, 2, 1), 'ST204'),
#  (datetime.date(2014, 2, 1), 'ST205'),
#  (datetime.date(2014, 2, 1), 'ST206'),
#  (datetime.date(2014, 2, 1), 'ST207'),
#  (datetime.date(2014, 2, 1), 'ST21'),
#  (datetime.date(2014, 2, 1), 'ST211'),
#  (datetime.date(2014, 2, 1), 'ST218'),
#  (datetime.date(2014, 2, 1), 'ST220'),
#  (datetime.date(2014, 2, 1), 'ST224'),
#  (datetime.date(2014, 2, 1), 'ST227'),
#  (datetime.date(2014, 2, 1), 'ST228'),
#  (datetime.date(2014, 2, 1), 'ST232'),
#  (datetime.date(2014, 2, 1), 'ST235'),
#  (datetime.date(2014, 2, 1), 'ST239'),
#  (datetime.date(2014, 2, 1), 'ST242'),
#  (datetime.date(2014, 2, 1), 'ST243'),
#  (datetime.date(2014, 2, 1), 'ST34'),
#  (datetime.date(2014, 2, 1), 'ST355'),
#  (datetime.date(2014, 2, 1), 'ST358'),
#  (datetime.date(2014, 2, 1), 'ST360'),
#  (datetime.date(2014, 2, 1), 'ST365'),
#  (datetime.date(2014, 2, 1), 'ST366'),
#  (datetime.date(2014, 2, 1), 'ST38'),
#  (datetime.date(2014, 2, 1), 'ST40'),
#  (datetime.date(2014, 2, 1), 'ST41'),
#  (datetime.date(2014, 2, 1), 'ST423'),
#  (datetime.date(2014, 2, 1), 'ST424'),
#  (datetime.date(2014, 2, 1), 'ST427'),
#  (datetime.date(2014, 2, 1), 'ST45'),
#  (datetime.date(2014, 2, 1), 'ST47'),
#  (datetime.date(2014, 2, 1), 'ST48'),
#  (datetime.date(2014, 2, 1), 'ST488'),
#  (datetime.date(2014, 2, 1), 'ST5'),
#  (datetime.date(2014, 2, 1), 'ST50'),
#  (datetime.date(2014, 2, 1), 'ST512'),
#  (datetime.date(2014, 2, 1), 'ST515'),
#  (datetime.date(2014, 2, 1), 'ST519'),
#  (datetime.date(2014, 2, 1), 'ST52'),
#  (datetime.date(2014, 2, 1), 'ST520'),
#  (datetime.date(2014, 2, 1), 'ST53'),
#  (datetime.date(2014, 2, 1), 'ST54'),
#  (datetime.date(2014, 2, 1), 'ST69'),
#  (datetime.date(2014, 2, 1), 'ST7'),
#  (datetime.date(2014, 2, 1), 'ST70'),
#  (datetime.date(2014, 2, 1), 'ST71'),
#  (datetime.date(2014, 2, 1), 'ST72'),
#  (datetime.date(2014, 2, 1), 'ST73'),
#  (datetime.date(2014, 2, 1), 'ST75'),
#  (datetime.date(2014, 2, 1), 'ST76'),
#  (datetime.date(2014, 2, 1), 'ST8'),
#  (datetime.date(2014, 2, 1), 'ST83'),
#  (datetime.date(2014, 2, 1), 'ST84'),
#  (datetime.date(2014, 2, 1), 'ST87'),
#  (datetime.date(2014, 2, 1), 'ST89'),
#  (datetime.date(2014, 2, 1), 'ST9'),
#  (datetime.date(2014, 2, 1), 'ST96'),
#  (datetime.date(2014, 2, 1), 'ST97'),
#  (datetime.date(2014, 2, 2), 'ST10'),
#  (datetime.date(2014, 2, 2), 'ST102'),
#  (datetime.date(2014, 2, 2), 'ST105'),
#  (datetime.date(2014, 2, 2), 'ST106'),
#  (datetime.date(2014, 2, 2), 'ST107'),
#  (datetime.date(2014, 2, 2), 'ST111'),
#  (datetime.date(2014, 2, 2), 'ST113'),
#  (datetime.date(2014, 2, 2), 'ST114'),
#  (datetime.date(2014, 2, 2), 'ST115'),
#  (datetime.date(2014, 2, 2), 'ST116'),
#  (datetime.date(2014, 2, 2), 'ST117'),
#  (datetime.date(2014, 2, 2), 'ST12'),
#  (datetime.date(2014, 2, 2), 'ST121'),
#  (datetime.date(2014, 2, 2), 'ST123'),
#  (datetime.date(2014, 2, 2), 'ST124'),
#  (datetime.date(2014, 2, 2), 'ST125'),
#  (datetime.date(2014, 2, 2), 'ST13'),
#  (datetime.date(2014, 2, 2), 'ST134'),
#  (datetime.date(2014, 2, 2), 'ST136'),
#  (datetime.date(2014, 2, 2), 'ST137'),
#  (datetime.date(2014, 2, 2), 'ST138')]

# %% [markdown]
# ### Query4
#
# Extracting Table for st_property_info

# %%
# %sql SELECT * FROM st_property_info Limit 244;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# [('ST1', 'L9531', 'R6'),
#  ('ST10', 'L9533', 'R6'),
#  ('ST100', 'L1944', 'R2'),
#  ('ST1000', 'L5957', 'R1'),
#  ('ST101', 'L15257', 'R2'),
#  ('ST102', 'L15257', 'R6'),
#  ('ST103', 'L15257', 'R10'),
#  ('ST104', 'L15257', 'R14'),
#  ('ST105', 'L15260', 'R2'),
#  ('ST106', 'L15260', 'R6'),
#  ('ST107', 'L15260', 'R10'),
#  ('ST108', 'L15260', 'R14'),
#  ('ST109', 'L15264', 'R2'),
#  ('ST11', 'L9533', 'R10'),
#  ('ST110', 'L15264', 'R6'),
#  ('ST111', 'L15264', 'R10'),
#  ('ST112', 'L15264', 'R14'),
#  ('ST113', 'L15278', 'R2'),
#  ('ST114', 'L15278', 'R6'),
#  ('ST115', 'L15278', 'R10'),
#  ('ST116', 'L15278', 'R14'),
#  ('ST117', 'L15280', 'R2'),
#  ('ST118', 'L15280', 'R6'),
#  ('ST119', 'L15280', 'R10'),
#  ('ST12', 'L9533', 'R14'),
#  ('ST120', 'L15280', 'R14'),
#  ('ST121', 'L463', 'R2'),
#  ('ST122', 'L463', 'R6'),
#  ('ST123', 'L463', 'R10'),
#  ('ST124', 'L463', 'R14'),
#  ('ST125', 'L464', 'R2'),
#  ('ST126', 'L464', 'R6'),
#  ('ST127', 'L464', 'R10'),
#  ('ST128', 'L464', 'R14'),
#  ('ST129', 'L2314', 'R2'),
#  ('ST13', 'L9534', 'R6'),
#  ('ST130', 'L2314', 'R6'),
#  ('ST131', 'L2314', 'R10'),
#  ('ST132', 'L2314', 'R14'),
#  ('ST133', 'L2318', 'R2'),
#  ('ST134', 'L2318', 'R6'),
#  ('ST135', 'L2318', 'R10'),
#  ('ST136', 'L2318', 'R14'),
#  ('ST137', 'L2323', 'R2'),
#  ('ST138', 'L2323', 'R6'),
#  ('ST139', 'L2323', 'R10'),
#  ('ST14', 'L9534', 'R10'),
#  ('ST140', 'L2323', 'R14'),
#  ('ST141', 'L2325', 'R2'),
#  ('ST142', 'L2325', 'R6'),
#  ('ST143', 'L2325', 'R10'),
#  ('ST144', 'L2325', 'R14'),
#  ('ST145', 'L2338', 'R2'),
#  ('ST146', 'L2338', 'R6'),
#  ('ST147', 'L2338', 'R10'),
#  ('ST148', 'L2338', 'R14'),
#  ('ST149', 'L3244', 'R2'),
#  ('ST15', 'L9534', 'R14'),
#  ('ST150', 'L3244', 'R6'),
#  ('ST151', 'L3244', 'R10'),
#  ('ST152', 'L3244', 'R14'),
#  ('ST153', 'L3256', 'R2'),
#  ('ST154', 'L3256', 'R6'),
#  ('ST155', 'L3256', 'R10'),
#  ('ST156', 'L3256', 'R14'),
#  ('ST157', 'L3261', 'R2'),
#  ('ST158', 'L3261', 'R6'),
#  ('ST159', 'L3261', 'R10'),
#  ('ST16', 'L9534', 'R2'),
#  ('ST160', 'L3261', 'R14'),
#  ('ST161', 'L3262', 'R2'),
#  ('ST162', 'L3262', 'R6'),
#  ('ST163', 'L3262', 'R10'),
#  ('ST164', 'L3262', 'R14'),
#  ('ST165', 'L3264', 'R2'),
#  ('ST166', 'L3264', 'R6'),
#  ('ST167', 'L3264', 'R10'),
#  ('ST168', 'L3264', 'R14'),
#  ('ST169', 'L10126', 'R2'),
#  ('ST17', 'L4761', 'R6'),
#  ('ST170', 'L10126', 'R6'),
#  ('ST171', 'L10126', 'R10'),
#  ('ST172', 'L10126', 'R14'),
#  ('ST173', 'L10130', 'R2'),
#  ('ST174', 'L10130', 'R6'),
#  ('ST175', 'L10130', 'R10'),
#  ('ST176', 'L10130', 'R14'),
#  ('ST177', 'L10133', 'R2'),
#  ('ST178', 'L10133', 'R6'),
#  ('ST179', 'L10133', 'R10'),
#  ('ST18', 'L4761', 'R10'),
#  ('ST180', 'L10133', 'R14'),
#  ('ST181', 'L10136', 'R2'),
#  ('ST182', 'L10136', 'R6'),
#  ('ST183', 'L10136', 'R10'),
#  ('ST184', 'L10136', 'R14'),
#  ('ST185', 'L1882', 'R2'),
#  ('ST186', 'L1882', 'R6'),
#  ('ST187', 'L1882', 'R10'),
#  ('ST188', 'L1882', 'R3'),
#  ('ST189', 'L1883', 'R13'),
#  ('ST19', 'L4761', 'R14'),
#  ('ST190', 'L1883', 'R1'),
#  ('ST191', 'L1883', 'R10'),
#  ('ST192', 'L1883', 'R14'),
#  ('ST193', 'L1887', 'R2'),
#  ('ST194', 'L1887', 'R6'),
#  ('ST195', 'L1887', 'R10'),
#  ('ST196', 'L1887', 'R14'),
#  ('ST197', 'L1902', 'R2'),
#  ('ST198', 'L1902', 'R6'),
#  ('ST199', 'L1902', 'R10'),
#  ('ST2', 'L9531', 'R10'),
#  ('ST20', 'L4761', 'R2'),
#  ('ST200', 'L1902', 'R14'),
#  ('ST201', 'L1916', 'R2'),
#  ('ST202', 'L1916', 'R6'),
#  ('ST203', 'L1916', 'R10'),
#  ('ST204', 'L1916', 'R14'),
#  ('ST205', 'L12252', 'R2'),
#  ('ST206', 'L12252', 'R6'),
#  ('ST207', 'L12252', 'R10'),
#  ('ST208', 'L12252', 'R14'),
#  ('ST209', 'L12260', 'R2'),
#  ('ST21', 'L4765', 'R6'),
#  ('ST210', 'L12260', 'R6'),
#  ('ST211', 'L12260', 'R10'),
#  ('ST212', 'L12260', 'R1'),
#  ('ST213', 'L12264', 'R4'),
#  ('ST214', 'L12264', 'R4'),
#  ('ST215', 'L12264', 'R1'),
#  ('ST216', 'L12264', 'R7'),
#  ('ST217', 'L16888', 'R8'),
#  ('ST218', 'L16888', 'R6'),
#  ('ST219', 'L16888', 'R10'),
#  ('ST22', 'L4765', 'R1'),
#  ('ST220', 'L16888', 'R14'),
#  ('ST221', 'L16887', 'R2'),
#  ('ST222', 'L16887', 'R6'),
#  ('ST223', 'L16887', 'R10'),
#  ('ST224', 'L16887', 'R14'),
#  ('ST225', 'L16898', 'R2'),
#  ('ST226', 'L16898', 'R6'),
#  ('ST227', 'L16898', 'R10'),
#  ('ST228', 'L16898', 'R14'),
#  ('ST229', 'L16890', 'R2'),
#  ('ST23', 'L4765', 'R5'),
#  ('ST230', 'L16890', 'R6'),
#  ('ST231', 'L16890', 'R10'),
#  ('ST232', 'L16890', 'R14'),
#  ('ST233', 'L14416', 'R7'),
#  ('ST234', 'L14416', 'R8'),
#  ('ST235', 'L14416', 'R10'),
#  ('ST236', 'L14416', 'R14'),
#  ('ST237', 'L14418', 'R2'),
#  ('ST238', 'L14418', 'R6'),
#  ('ST239', 'L14418', 'R10'),
#  ('ST24', 'L4765', 'R16'),
#  ('ST240', 'L14418', 'R14'),
#  ('ST241', 'L14419', 'R2'),
#  ('ST242', 'L14419', 'R6'),
#  ('ST243', 'L14419', 'R10'),
#  ('ST244', 'L14419', 'R14'),
#  ('ST245', 'L18168', 'R4'),
#  ('ST246', 'L12651', 'R12'),
#  ('ST247', 'L14129', 'R16'),
#  ('ST248', 'L9526', 'R8'),
#  ('ST249', 'L16463', 'R4'),
#  ('ST25', 'L4770', 'R7'),
#  ('ST250', 'L2926', 'R9'),
#  ('ST251', 'L13927', 'R9'),
#  ('ST252', 'L13182', 'R8'),
#  ('ST253', 'L9440', 'R1'),
#  ('ST254', 'L1882', 'R7'),
#  ('ST255', 'L16573', 'R15'),
#  ('ST256', 'L8234', 'R15'),
#  ('ST257', 'L5257', 'R11'),
#  ('ST258', 'L18040', 'R16'),
#  ('ST259', 'L13288', 'R3'),
#  ('ST26', 'L4770', 'R1'),
#  ('ST260', 'L11609', 'R7'),
#  ('ST261', 'L1532', 'R8'),
#  ('ST262', 'L3248', 'R16'),
#  ('ST263', 'L10078', 'R7'),
#  ('ST264', 'L8616', 'R4'),
#  ('ST265', 'L15033', 'R4'),
#  ('ST266', 'L337', 'R3'),
#  ('ST267', 'L18143', 'R8'),
#  ('ST268', 'L14892', 'R7'),
#  ('ST269', 'L12500', 'R16'),
#  ('ST27', 'L4770', 'R5'),
#  ('ST270', 'L15383', 'R4'),
#  ('ST271', 'L10046', 'R4'),
#  ('ST272', 'L910', 'R5'),
#  ('ST273', 'L15619', 'R8'),
#  ('ST274', 'L6791', 'R11'),
#  ('ST275', 'L10758', 'R7'),
#  ('ST276', 'L18023', 'R15'),
#  ('ST277', 'L8940', 'R15'),
#  ('ST278', 'L5592', 'R5'),
#  ('ST279', 'L11377', 'R8'),
#  ('ST28', 'L4770', 'R16'),
#  ('ST280', 'L17825', 'R4'),
#  ('ST281', 'L7592', 'R7'),
#  ('ST282', 'L6398', 'R15'),
#  ('ST283', 'L6916', 'R13'),
#  ('ST284', 'L13997', 'R9'),
#  ('ST285', 'L10339', 'R4'),
#  ('ST286', 'L5218', 'R3'),
#  ('ST287', 'L3015', 'R4'),
#  ('ST288', 'L2424', 'R7'),
#  ('ST289', 'L13082', 'R4'),
#  ('ST29', 'L4794', 'R7'),
#  ('ST290', 'L5169', 'R15'),
#  ('ST291', 'L15700', 'R5'),
#  ('ST292', 'L6958', 'R16'),
#  ('ST293', 'L17610', 'R16'),
#  ('ST294', 'L6588', 'R16'),
#  ('ST295', 'L11784', 'R13'),
#  ('ST296', 'L4322', 'R16'),
#  ('ST297', 'L11399', 'R13'),
#  ('ST298', 'L186', 'R16'),
#  ('ST299', 'L9096', 'R12'),
#  ('ST3', 'L9531', 'R14'),
#  ('ST30', 'L4794', 'R3'),
#  ('ST300', 'L5448', 'R11'),
#  ('ST301', 'L4932', 'R16'),
#  ('ST302', 'L3464', 'R9'),
#  ('ST303', 'L14193', 'R15'),
#  ('ST304', 'L16352', 'R1'),
#  ('ST305', 'L5609', 'R5'),
#  ('ST306', 'L12020', 'R16'),
#  ('ST307', 'L3310', 'R8'),
#  ('ST308', 'L15437', 'R5'),
#  ('ST309', 'L8388', 'R16'),
#  ('ST31', 'L4794', 'R14'),
#  ('ST310', 'L15653', 'R3'),
#  ('ST311', 'L4772', 'R7'),
#  ('ST312', 'L1821', 'R8'),
#  ('ST313', 'L1567', 'R4'),
#  ('ST314', 'L16007', 'R5'),
#  ('ST315', 'L4030', 'R9'),
#  ('ST316', 'L17781', 'R1'),
#  ('ST317', 'L2326', 'R5')]

# %% [markdown]
# ### JOIN QUERY
#
# Joining tables with same foreign keys

# %%
# %sql SELECT DISTINCT w.ws_property_id,w.location, w.property_type,w.current_monthly_rent,srp.percentile_10th_price,srp.percentile_90th_price,srp.sample_nightly_rent_price,srd.rental_date,srd.st_property, COUNT(srd.rental_date)/365 AS occupancy_rate,p.apt_house,p.num_bedrooms,p.kitchen,p.shared,l.city,l.state,l.zipcode FROM watershed_property_info w JOIN st_property_info spi ON (w.location=spi.location AND w.property_type=spi.property_type) JOIN st_rental_prices srp ON (spi.location=srp.location AND spi.property_type=srp.property_type) JOIN property_type p ON w.property_type=p.property_type_id JOIN location l ON w.location=l.location_id JOIN st_rental_dates srd ON spi.st_property_id = srd.st_property WHERE YEAR(srd.rental_date)=2015 GROUP BY srd.st_property;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# [('W1', 'L9531', 'R6', 1060, 114, 153, 148, datetime.date(2015, 1, 1), 'ST1', Decimal('0.1616'), 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27514),
#  ('W10', 'L9533', 'R6', 1200, 111, 149, 133, datetime.date(2015, 1, 5), 'ST10', Decimal('0.3479'), 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27517),
#  ('W100', 'L1944', 'R2', 3300, 108, 610, 372, datetime.date(2015, 1, 7), 'ST100', Decimal('0.3973'), 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94129),
#  ('W101', 'L15257', 'R2', 1400, 178, 533, 302, datetime.date(2015, 1, 2), 'ST101', Decimal('0.3644'), 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78702),
#  ('W102', 'L15257', 'R6', 2000, 221, 617, 429, datetime.date(2015, 1, 4), 'ST102', Decimal('0.4110'), 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78702),
#  ('W103', 'L15257', 'R10', 1600, 202, 646, 380, datetime.date(2015, 1, 4), 'ST103', Decimal('0.4110'), 'house', '1', 'Y', 'N', 'Austin', 'TX', 78702),
#  ('W104', 'L15257', 'R14', 2800, 197, 639, 374, datetime.date(2015, 1, 3), 'ST104', Decimal('0.5260'), 'house', '2', 'Y', 'N', 'Austin', 'TX', 78702),
#  ('W105', 'L15260', 'R2', 1100, 114, 477, 386, datetime.date(2015, 1, 1), 'ST105', Decimal('0.4329'), 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78705),
#  ('W106', 'L15260', 'R6', 1900, 80, 583, 212, datetime.date(2015, 1, 1), 'ST106', Decimal('0.6959'), 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78705),
#  ('W107', 'L15260', 'R10', 1800, 239, 1431, 969, datetime.date(2015, 1, 4), 'ST107', Decimal('0.1096'), 'house', '1', 'Y', 'N', 'Austin', 'TX', 78705),
#  ('W108', 'L15260', 'R14', 3200, 236, 1533, 885, datetime.date(2015, 1, 1), 'ST108', Decimal('0.2247'), 'house', '2', 'Y', 'N', 'Austin', 'TX', 78705),
#  ('W109', 'L15264', 'R2', 1000, 138, 550, 287, datetime.date(2015, 1, 7), 'ST109', Decimal('0.2192'), 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78723),
#  ('W11', 'L9533', 'R10', 1000, 116, 296, 206, datetime.date(2015, 1, 2), 'ST11', Decimal('0.3918'), 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27517),
#  ('W110', 'L15264', 'R6', 1300, 175, 917, 462, datetime.date(2015, 1, 3), 'ST110', Decimal('0.5370'), 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78723),
#  ('W111', 'L15264', 'R10', 1200, 130, 821, 389, datetime.date(2015, 1, 2), 'ST111', Decimal('0.5123'), 'house', '1', 'Y', 'N', 'Austin', 'TX', 78723),
#  ('W112', 'L15264', 'R14', 1600, 241, 866, 678, datetime.date(2015, 1, 1), 'ST112', Decimal('0.3616'), 'house', '2', 'Y', 'N', 'Austin', 'TX', 78723),
#  ('W113', 'L15278', 'R2', 800, 134, 288, 163, datetime.date(2015, 1, 1), 'ST113', Decimal('0.8438'), 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78744),
#  ('W114', 'L15278', 'R6', 1200, 234, 794, 374, datetime.date(2015, 1, 3), 'ST114', Decimal('0.9151'), 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78744),
#  ('W115', 'L15278', 'R10', 900, 252, 547, 444, datetime.date(2015, 1, 1), 'ST115', Decimal('0.4301'), 'house', '1', 'Y', 'N', 'Austin', 'TX', 78744),
#  ('W116', 'L15278', 'R14', 1100, 246, 616, 426, datetime.date(2015, 1, 3), 'ST116', Decimal('0.4822'), 'house', '2', 'Y', 'N', 'Austin', 'TX', 78744),
#  ('W117', 'L15280', 'R2', 1000, 171, 457, 332, datetime.date(2015, 1, 1), 'ST117', Decimal('0.4904'), 'apartment', '1', 'Y', 'N', 'Austin', 'TX', 78746),
#  ('W118', 'L15280', 'R6', 1400, 262, 567, 430, datetime.date(2015, 1, 1), 'ST118', Decimal('0.5233'), 'apartment', '2', 'Y', 'N', 'Austin', 'TX', 78746),
#  ('W119', 'L15280', 'R10', 1500, 229, 859, 662, datetime.date(2015, 1, 4), 'ST119', Decimal('0.4493'), 'house', '1', 'Y', 'N', 'Austin', 'TX', 78746),
#  ('W12', 'L9533', 'R14', 1300, 136, 336, 186, datetime.date(2015, 1, 1), 'ST12', Decimal('0.6603'), 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27517),
#  ('W120', 'L15280', 'R14', 1600, 449, 899, 696, datetime.date(2015, 1, 2), 'ST120', Decimal('0.4877'), 'house', '2', 'Y', 'N', 'Austin', 'TX', 78746),
#  ('W121', 'L463', 'R2', 600, 132, 226, 182, datetime.date(2015, 1, 2), 'ST121', Decimal('0.4384'), 'apartment', '1', 'Y', 'N', 'Bentonville', 'AR', 72712),
#  ('W122', 'L463', 'R6', 800, 157, 340, 241, datetime.date(2015, 1, 1), 'ST122', Decimal('0.5315'), 'apartment', '2', 'Y', 'N', 'Bentonville', 'AR', 72712),
#  ('W123', 'L463', 'R10', 700, 215, 377, 363, datetime.date(2015, 1, 3), 'ST123', Decimal('0.1397'), 'house', '1', 'Y', 'N', 'Bentonville', 'AR', 72712),
#  ('W124', 'L463', 'R14', 1000, 202, 374, 301, datetime.date(2015, 1, 3), 'ST124', Decimal('0.4685'), 'house', '2', 'Y', 'N', 'Bentonville', 'AR', 72712),
#  ('W125', 'L464', 'R2', 700, 94, 356, 212, datetime.date(2015, 1, 1), 'ST125', Decimal('0.5014'), 'apartment', '1', 'Y', 'N', 'Bentonville', 'AR', 72719),
#  ('W126', 'L464', 'R6', 900, 69, 485, 340, datetime.date(2015, 1, 1), 'ST126', Decimal('0.3068'), 'apartment', '2', 'Y', 'N', 'Bentonville', 'AR', 72719),
#  ('W127', 'L464', 'R10', 1000, 84, 376, 266, datetime.date(2015, 1, 1), 'ST127', Decimal('0.5205'), 'house', '1', 'Y', 'N', 'Bentonville', 'AR', 72719),
#  ('W128', 'L464', 'R14', 1200, 109, 490, 442, datetime.date(2015, 1, 2), 'ST128', Decimal('0.1288'), 'house', '2', 'Y', 'N', 'Bentonville', 'AR', 72719),
#  ('W129', 'L2314', 'R2', 1200, 145, 434, 354, datetime.date(2015, 1, 5), 'ST129', Decimal('0.2411'), 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80204),
#  ('W13', 'L9534', 'R6', 920, 111, 147, 123, datetime.date(2015, 1, 1), 'ST13', Decimal('0.4521'), 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27707),
#  ('W130', 'L2314', 'R6', 1300, 228, 457, 377, datetime.date(2015, 1, 1), 'ST130', Decimal('0.4795'), 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80204),
#  ('W131', 'L2314', 'R10', 1100, 90, 375, 318, datetime.date(2015, 1, 10), 'ST131', Decimal('0.2712'), 'house', '1', 'Y', 'N', 'Denver', 'CO', 80204),
#  ('W132', 'L2314', 'R14', 1200, 128, 238, 198, datetime.date(2015, 1, 4), 'ST132', Decimal('0.4301'), 'house', '2', 'Y', 'N', 'Denver', 'CO', 80204),
#  ('W133', 'L2318', 'R2', 1300, 126, 188, 149, datetime.date(2015, 1, 1), 'ST133', Decimal('0.5671'), 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80209),
#  ('W134', 'L2318', 'R6', 1700, 152, 247, 210, datetime.date(2015, 1, 4), 'ST134', Decimal('0.3205'), 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80209),
#  ('W135', 'L2318', 'R10', 1200, 141, 263, 187, datetime.date(2015, 1, 3), 'ST135', Decimal('0.4493'), 'house', '1', 'Y', 'N', 'Denver', 'CO', 80209),
#  ('W136', 'L2318', 'R14', 1900, 157, 314, 225, datetime.date(2015, 1, 1), 'ST136', Decimal('0.5096'), 'house', '2', 'Y', 'N', 'Denver', 'CO', 80209),
#  ('W137', 'L2323', 'R2', 1000, 93, 159, 123, datetime.date(2015, 1, 2), 'ST137', Decimal('0.7205'), 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80218),
#  ('W138', 'L2323', 'R6', 1500, 145, 462, 263, datetime.date(2015, 1, 1), 'ST138', Decimal('0.4959'), 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80218),
#  ('W139', 'L2323', 'R10', 1300, 181, 316, 238, datetime.date(2015, 1, 2), 'ST139', Decimal('0.4493'), 'house', '1', 'Y', 'N', 'Denver', 'CO', 80218),
#  ('W14', 'L9534', 'R10', 850, 96, 245, 146, datetime.date(2015, 1, 1), 'ST14', Decimal('0.5315'), 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27707),
#  ('W140', 'L2323', 'R14', 1800, 145, 412, 349, datetime.date(2015, 1, 6), 'ST140', Decimal('0.1507'), 'house', '2', 'Y', 'N', 'Denver', 'CO', 80218),
#  ('W141', 'L2325', 'R2', 1100, 99, 215, 147, datetime.date(2015, 1, 1), 'ST141', Decimal('0.6000'), 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80220),
#  ('W142', 'L2325', 'R6', 1400, 120, 188, 151, datetime.date(2015, 1, 1), 'ST142', Decimal('0.5260'), 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80220),
#  ('W143', 'L2325', 'R10', 1300, 263, 489, 429, datetime.date(2015, 1, 13), 'ST143', Decimal('0.2110'), 'house', '1', 'Y', 'N', 'Denver', 'CO', 80220),
#  ('W144', 'L2325', 'R14', 1900, 335, 502, 441, datetime.date(2015, 1, 4), 'ST144', Decimal('0.3315'), 'house', '2', 'Y', 'N', 'Denver', 'CO', 80220),
#  ('W145', 'L2338', 'R2', 900, 98, 195, 144, datetime.date(2015, 1, 8), 'ST145', Decimal('0.3288'), 'apartment', '1', 'Y', 'N', 'Denver', 'CO', 80249),
#  ('W146', 'L2338', 'R6', 1400, 77, 260, 136, datetime.date(2015, 1, 1), 'ST146', Decimal('0.6192'), 'apartment', '2', 'Y', 'N', 'Denver', 'CO', 80249),
#  ('W147', 'L2338', 'R10', 1400, 173, 322, 305, datetime.date(2015, 1, 9), 'ST147', Decimal('0.2712'), 'house', '1', 'Y', 'N', 'Denver', 'CO', 80249),
#  ('W148', 'L2338', 'R14', 1700, 176, 469, 425, datetime.date(2015, 1, 1), 'ST148', Decimal('0.3288'), 'house', '2', 'Y', 'N', 'Denver', 'CO', 80249),
#  ('W149', 'L3244', 'R2', 800, 86, 224, 176, datetime.date(2015, 1, 1), 'ST149', Decimal('0.4137'), 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33122),
#  ('W15', 'L9534', 'R14', 900, 111, 276, 169, datetime.date(2015, 1, 3), 'ST15', Decimal('0.4795'), 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27707),
#  ('W150', 'L3244', 'R6', 1300, 127, 276, 207, datetime.date(2015, 1, 2), 'ST150', Decimal('0.6301'), 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33122),
#  ('W151', 'L3244', 'R10', 1400, 222, 381, 244, datetime.date(2015, 1, 1), 'ST151', Decimal('0.9041'), 'house', '1', 'Y', 'N', 'Miami', 'FL', 33122),
#  ('W152', 'L3244', 'R14', 1900, 386, 773, 536, datetime.date(2015, 1, 2), 'ST152', Decimal('0.5425'), 'house', '2', 'Y', 'N', 'Miami', 'FL', 33122),
#  ('W153', 'L3256', 'R2', 1700, 136, 476, 476, datetime.date(2015, 1, 1), 'ST153', Decimal('0.0795'), 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33137),
#  ('W154', 'L3256', 'R6', 2400, 173, 690, 360, datetime.date(2015, 1, 1), 'ST154', Decimal('0.5507'), 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33137),
#  ('W155', 'L3256', 'R10', 2100, 448, 2128, 1477, datetime.date(2015, 1, 1), 'ST155', Decimal('0.6932'), 'house', '1', 'Y', 'N', 'Miami', 'FL', 33137),
#  ('W156', 'L3256', 'R14', 3200, 450, 2699, 1265, datetime.date(2015, 1, 2), 'ST156', Decimal('0.7151'), 'house', '2', 'Y', 'N', 'Miami', 'FL', 33137),
#  ('W157', 'L3261', 'R2', 1300, 291, 387, 328, datetime.date(2015, 1, 4), 'ST157', Decimal('0.5205'), 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33146),
#  ('W158', 'L3261', 'R6', 1700, 203, 318, 246, datetime.date(2015, 1, 2), 'ST158', Decimal('0.1589'), 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33146),
#  ('W159', 'L3261', 'R10', 1400, 287, 395, 325, datetime.date(2015, 1, 1), 'ST159', Decimal('0.5452'), 'house', '1', 'Y', 'N', 'Miami', 'FL', 33146),
#  ('W16', 'L9534', 'R2', 750, 51, 179, 94, datetime.date(2015, 1, 2), 'ST16', Decimal('0.4795'), 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27707),
#  ('W160', 'L3261', 'R14', 1900, 376, 502, 428, datetime.date(2015, 1, 1), 'ST160', Decimal('0.5863'), 'house', '2', 'Y', 'N', 'Miami', 'FL', 33146),
#  ('W161', 'L3262', 'R2', 1600, 126, 352, 188, datetime.date(2015, 1, 2), 'ST161', Decimal('0.6795'), 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33149),
#  ('W162', 'L3262', 'R6', 2200, 119, 505, 274, datetime.date(2015, 1, 2), 'ST162', Decimal('0.5781'), 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33149),
#  ('W163', 'L3262', 'R10', 1500, 486, 1215, 860, datetime.date(2015, 1, 2), 'ST163', Decimal('0.4110'), 'house', '1', 'Y', 'N', 'Miami', 'FL', 33149),
#  ('W164', 'L3262', 'R14', 2400, 516, 1650, 729, datetime.date(2015, 1, 1), 'ST164', Decimal('0.6822'), 'house', '2', 'Y', 'N', 'Miami', 'FL', 33149),
#  ('W165', 'L3264', 'R2', 1600, 160, 321, 174, datetime.date(2015, 1, 1), 'ST165', Decimal('0.8247'), 'apartment', '1', 'Y', 'N', 'Miami', 'FL', 33178),
#  ('W166', 'L3264', 'R6', 1900, 168, 364, 308, datetime.date(2015, 1, 2), 'ST166', Decimal('0.2164'), 'apartment', '2', 'Y', 'N', 'Miami', 'FL', 33178),
#  ('W167', 'L3264', 'R10', 1400, 226, 368, 308, datetime.date(2015, 1, 1), 'ST167', Decimal('0.6000'), 'house', '1', 'Y', 'N', 'Miami', 'FL', 33178),
#  ('W168', 'L3264', 'R14', 2000, 285, 428, 342, datetime.date(2015, 1, 1), 'ST168', Decimal('0.3918'), 'house', '2', 'Y', 'N', 'Miami', 'FL', 33178),
#  ('W169', 'L10126', 'R2', 1000, 91, 342, 229, datetime.date(2015, 1, 1), 'ST169', Decimal('0.5890'), 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68046),
#  ('W17', 'L4761', 'R6', 2500, 173, 581, 392, datetime.date(2015, 1, 1), 'ST17', Decimal('0.2932'), 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60607),
#  ('W170', 'L10126', 'R6', 1400, 168, 392, 322, datetime.date(2015, 1, 2), 'ST170', Decimal('0.2712'), 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68046),
#  ('W171', 'L10126', 'R10', 1300, 155, 494, 257, datetime.date(2015, 1, 1), 'ST171', Decimal('0.5507'), 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68046),
#  ('W172', 'L10126', 'R14', 1800, 151, 391, 286, datetime.date(2015, 1, 3), 'ST172', Decimal('0.4521'), 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68046),
#  ('W173', 'L10130', 'R2', 700, 99, 265, 180, datetime.date(2015, 1, 4), 'ST173', Decimal('0.5178'), 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68106),
#  ('W174', 'L10130', 'R6', 900, 154, 286, 230, datetime.date(2015, 1, 1), 'ST174', Decimal('0.5205'), 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68106),
#  ('W175', 'L10130', 'R10', 1000, 190, 462, 221, datetime.date(2015, 1, 1), 'ST175', Decimal('0.6301'), 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68106),
#  ('W176', 'L10130', 'R14', 1200, 205, 411, 316, datetime.date(2015, 1, 5), 'ST176', Decimal('0.3699'), 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68106),
#  ('W177', 'L10133', 'R2', 700, 192, 313, 245, datetime.date(2015, 1, 1), 'ST177', Decimal('0.5699'), 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68110),
#  ('W178', 'L10133', 'R6', 1000, 192, 357, 266, datetime.date(2015, 1, 1), 'ST178', Decimal('0.4192'), 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68110),
#  ('W179', 'L10133', 'R10', 800, 186, 465, 325, datetime.date(2015, 1, 1), 'ST179', Decimal('0.4548'), 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68110),
#  ('W18', 'L4761', 'R10', 2500, 189, 588, 393, datetime.date(2015, 1, 2), 'ST18', Decimal('0.6219'), 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60607),
#  ('W180', 'L10133', 'R14', 900, 209, 358, 256, datetime.date(2015, 1, 1), 'ST180', Decimal('0.7096'), 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68110),
#  ('W181', 'L10136', 'R2', 700, 42, 252, 184, datetime.date(2015, 1, 1), 'ST181', Decimal('0.3096'), 'apartment', '1', 'Y', 'N', 'Omaha', 'NE', 68114),
#  ('W182', 'L10136', 'R6', 1000, 94, 531, 427, datetime.date(2015, 1, 8), 'ST182', Decimal('0.2411'), 'apartment', '2', 'Y', 'N', 'Omaha', 'NE', 68114),
#  ('W183', 'L10136', 'R10', 900, 86, 488, 418, datetime.date(2015, 1, 11), 'ST183', Decimal('0.0466'), 'house', '1', 'Y', 'N', 'Omaha', 'NE', 68114),
#  ('W184', 'L10136', 'R14', 1200, 83, 556, 219, datetime.date(2015, 1, 1), 'ST184', Decimal('0.6356'), 'house', '2', 'Y', 'N', 'Omaha', 'NE', 68114),
#  ('W185', 'L1882', 'R2', 1100, 84, 301, 220, datetime.date(2015, 1, 1), 'ST185', Decimal('0.4301'), 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 91910),
#  ('W186', 'L1882', 'R6', 1400, 134, 568, 481, datetime.date(2015, 1, 3), 'ST186', Decimal('0.3808'), 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 91910),
#  ('W187', 'L1882', 'R10', 1300, 109, 615, 280, datetime.date(2015, 1, 1), 'ST187', Decimal('0.4575'), 'house', '1', 'Y', 'N', 'San Diego', 'CA', 91910),
#  ('W19', 'L4761', 'R14', 2800, 191, 826, 556, datetime.date(2015, 1, 3), 'ST19', Decimal('0.2986'), 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60607),
#  ('W191', 'L1883', 'R10', 1300, 157, 471, 318, datetime.date(2015, 1, 2), 'ST191', Decimal('0.3918'), 'house', '1', 'Y', 'N', 'San Diego', 'CA', 91950),
#  ('W192', 'L1883', 'R14', 1600, 253, 886, 680, datetime.date(2015, 1, 13), 'ST192', Decimal('0.3863'), 'house', '2', 'Y', 'N', 'San Diego', 'CA', 91950),
#  ('W193', 'L1887', 'R2', 1400, 76, 342, 202, datetime.date(2015, 1, 1), 'ST193', Decimal('0.4877'), 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 92102),
#  ('W194', 'L1887', 'R6', 2000, 107, 781, 579, datetime.date(2015, 1, 2), 'ST194', Decimal('0.4110'), 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 92102),
#  ('W195', 'L1887', 'R10', 1700, 162, 614, 524, datetime.date(2015, 1, 1), 'ST195', Decimal('0.5041'), 'house', '1', 'Y', 'N', 'San Diego', 'CA', 92102),
#  ('W196', 'L1887', 'R14', 2500, 158, 906, 560, datetime.date(2015, 1, 2), 'ST196', Decimal('0.2767'), 'house', '2', 'Y', 'N', 'San Diego', 'CA', 92102),
#  ('W197', 'L1902', 'R2', 1800, 199, 432, 362, datetime.date(2015, 1, 1), 'ST197', Decimal('0.3288'), 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 92118),
#  ('W198', 'L1902', 'R6', 2600, 366, 594, 417, datetime.date(2015, 1, 1), 'ST198', Decimal('0.5315'), 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 92118),
#  ('W199', 'L1902', 'R10', 2500, 333, 665, 474, datetime.date(2015, 1, 3), 'ST199', Decimal('0.4274'), 'house', '1', 'Y', 'N', 'San Diego', 'CA', 92118),
#  ('W2', 'L9531', 'R10', 1500, 81, 205, 146, datetime.date(2015, 1, 1), 'ST2', Decimal('0.2411'), 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27514),
#  ('W20', 'L4761', 'R2', 1700, 106, 465, 312, datetime.date(2015, 1, 2), 'ST20', Decimal('0.4110'), 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60607),
#  ('W200', 'L1902', 'R14', 3600, 336, 624, 491, datetime.date(2015, 1, 5), 'ST200', Decimal('0.3973'), 'house', '2', 'Y', 'N', 'San Diego', 'CA', 92118),
#  ('W201', 'L1916', 'R2', 1200, 173, 395, 204, datetime.date(2015, 1, 2), 'ST201', Decimal('0.7973'), 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 92154),
#  ('W202', 'L1916', 'R6', 1600, 228, 456, 245, datetime.date(2015, 1, 1), 'ST202', Decimal('0.6877'), 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 92154),
#  ('W203', 'L1916', 'R10', 1000, 155, 252, 197, datetime.date(2015, 1, 1), 'ST203', Decimal('0.5890'), 'house', '1', 'Y', 'N', 'San Diego', 'CA', 92154),
#  ('W204', 'L1916', 'R14', 1500, 158, 236, 195, datetime.date(2015, 1, 1), 'ST204', Decimal('0.6192'), 'house', '2', 'Y', 'N', 'San Diego', 'CA', 92154),
#  ('W205', 'L12252', 'R2', 750, 89, 155, 124, datetime.date(2015, 1, 1), 'ST205', Decimal('0.4548'), 'apartment', '1', 'Y', 'N', 'Columbus', 'OH', 43201),
#  ('W206', 'L12252', 'R6', 1040, 115, 179, 156, datetime.date(2015, 1, 2), 'ST206', Decimal('0.4877'), 'apartment', '2', 'Y', 'N', 'Columbus', 'OH', 43201),
#  ('W207', 'L12252', 'R10', 900, 152, 300, 256, datetime.date(2015, 1, 4), 'ST207', Decimal('0.4795'), 'house', '1', 'Y', 'N', 'Columbus', 'OH', 43201),
#  ('W208', 'L12252', 'R14', 1400, 175, 368, 284, datetime.date(2015, 1, 1), 'ST208', Decimal('0.4932'), 'house', '2', 'Y', 'N', 'Columbus', 'OH', 43201),
#  ('W209', 'L12260', 'R2', 825, 77, 161, 128, datetime.date(2015, 1, 11), 'ST209', Decimal('0.3616'), 'apartment', '1', 'Y', 'N', 'Columbus', 'OH', 43212),
#  ('W21', 'L4765', 'R6', 2700, 157, 526, 337, datetime.date(2015, 1, 1), 'ST21', Decimal('0.4219'), 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60611),
#  ('W210', 'L12260', 'R6', 1300, 125, 170, 139, datetime.date(2015, 1, 2), 'ST210', Decimal('0.7425'), 'apartment', '2', 'Y', 'N', 'Columbus', 'OH', 43212),
#  ('W211', 'L12260', 'R10', 1000, 140, 288, 240, datetime.date(2015, 1, 2), 'ST211', Decimal('0.3699'), 'house', '1', 'Y', 'N', 'Columbus', 'OH', 43212),
#  ('W218', 'L16888', 'R6', 1200, 125, 277, 203, datetime.date(2015, 1, 6), 'ST218', Decimal('0.2712'), 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23113),
#  ('W219', 'L16888', 'R10', 1400, 209, 384, 240, datetime.date(2015, 1, 1), 'ST219', Decimal('0.7616'), 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23113),
#  ('W220', 'L16888', 'R14', 1600, 220, 418, 312, datetime.date(2015, 1, 1), 'ST220', Decimal('0.6082'), 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23113),
#  ('W221', 'L16887', 'R2', 1105, 82, 235, 111, datetime.date(2015, 1, 1), 'ST221', Decimal('0.6110'), 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23060),
#  ('W222', 'L16887', 'R6', 1665, 130, 200, 169, datetime.date(2015, 1, 3), 'ST222', Decimal('0.3068'), 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23060),
#  ('W223', 'L16887', 'R10', 1175, 106, 267, 201, datetime.date(2015, 1, 1), 'ST223', Decimal('0.5233'), 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23060),
#  ('W224', 'L16887', 'R14', 1725, 195, 305, 242, datetime.date(2015, 1, 1), 'ST224', Decimal('0.4822'), 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23060),
#  ('W225', 'L16898', 'R2', 709, 86, 192, 158, datetime.date(2015, 1, 1), 'ST225', Decimal('0.2219'), 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23234),
#  ('W226', 'L16898', 'R6', 869, 135, 305, 246, datetime.date(2015, 1, 2), 'ST226', Decimal('0.3890'), 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23234),
#  ('W227', 'L16898', 'R10', 925, 125, 288, 207, datetime.date(2015, 1, 2), 'ST227', Decimal('0.4164'), 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23234),
#  ('W228', 'L16898', 'R14', 1350, 119, 360, 224, datetime.date(2015, 1, 4), 'ST228', Decimal('0.4849'), 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23234),
#  ('W229', 'L16890', 'R2', 900, 89, 177, 139, datetime.date(2015, 1, 1), 'ST229', Decimal('0.5507'), 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23220),
#  ('W230', 'L16890', 'R6', 1325, 161, 319, 283, datetime.date(2015, 1, 1), 'ST230', Decimal('0.2932'), 'apartment', '2', 'Y', 'N', 'Richmond', 'VA', 23220),
#  ('W231', 'L16890', 'R10', 975, 145, 300, 192, datetime.date(2015, 1, 1), 'ST231', Decimal('0.5014'), 'house', '1', 'Y', 'N', 'Richmond', 'VA', 23220),
#  ('W232', 'L16890', 'R14', 1550, 185, 376, 307, datetime.date(2015, 1, 1), 'ST232', Decimal('0.3014'), 'house', '2', 'Y', 'N', 'Richmond', 'VA', 23220),
#  ('W235', 'L14416', 'R10', 1400, 135, 287, 232, datetime.date(2015, 1, 4), 'ST235', Decimal('0.4986'), 'house', '1', 'Y', 'N', 'Charleston', 'SC', 29438),
#  ('W236', 'L14416', 'R14', 1995, 224, 331, 292, datetime.date(2015, 1, 3), 'ST236', Decimal('0.6384'), 'house', '2', 'Y', 'N', 'Charleston', 'SC', 29438),
#  ('W237', 'L14418', 'R2', 760, 100, 195, 169, datetime.date(2015, 1, 5), 'ST237', Decimal('0.2904'), 'apartment', '1', 'Y', 'N', 'Charleston', 'SC', 29470),
#  ('W238', 'L14418', 'R6', 965, 135, 284, 189, datetime.date(2015, 1, 2), 'ST238', Decimal('0.5397'), 'apartment', '2', 'Y', 'N', 'Charleston', 'SC', 29470),
#  ('W239', 'L14418', 'R10', 1185, 157, 320, 289, datetime.date(2015, 1, 7), 'ST239', Decimal('0.2795'), 'house', '1', 'Y', 'N', 'Charleston', 'SC', 29470),
#  ('W240', 'L14418', 'R14', 1340, 135, 347, 278, datetime.date(2015, 1, 3), 'ST240', Decimal('0.3890'), 'house', '2', 'Y', 'N', 'Charleston', 'SC', 29470),
#  ('W241', 'L14419', 'R2', 1150, 80, 267, 183, datetime.date(2015, 1, 2), 'ST241', Decimal('0.5753'), 'apartment', '1', 'Y', 'N', 'Charleston', 'SC', 29487),
#  ('W242', 'L14419', 'R6', 2000, 160, 323, 237, datetime.date(2015, 1, 1), 'ST242', Decimal('0.3123'), 'apartment', '2', 'Y', 'N', 'Charleston', 'SC', 29487),
#  ('W243', 'L14419', 'R10', 1600, 225, 406, 297, datetime.date(2015, 1, 1), 'ST243', Decimal('0.4521'), 'house', '1', 'Y', 'N', 'Charleston', 'SC', 29487),
#  ('W244', 'L14419', 'R14', 2150, 170, 447, 360, datetime.date(2015, 1, 1), 'ST244', Decimal('0.5315'), 'house', '2', 'Y', 'N', 'Charleston', 'SC', 29487),
#  ('W3', 'L9531', 'R14', 2000, 97, 240, 199, datetime.date(2015, 1, 3), 'ST3', Decimal('0.3123'), 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27514),
#  ('W31', 'L4794', 'R14', 2750, 188, 810, 538, datetime.date(2015, 1, 1), 'ST31', Decimal('0.6000'), 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60642),
#  ('W32', 'L4794', 'R2', 1800, 89, 390, 288, datetime.date(2015, 1, 1), 'ST32', Decimal('0.2329'), 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60642),
#  ('W33', 'L4804', 'R6', 3000, 193, 648, 415, datetime.date(2015, 1, 2), 'ST33', Decimal('0.4082'), 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60654),
#  ('W34', 'L4804', 'R10', 2000, 193, 600, 387, datetime.date(2015, 1, 1), 'ST34', Decimal('0.3260'), 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60654),
#  ('W35', 'L4804', 'R14', 2950, 192, 829, 575, datetime.date(2015, 1, 4), 'ST35', Decimal('0.3890'), 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60654),
#  ('W55', 'L11480', 'R14', 3000, 195, 752, 620, datetime.date(2015, 1, 1), 'ST355', Decimal('0.2932'), 'house', '2', 'Y', 'N', 'New York', 'NY', 11101),
#  ('W56', 'L11480', 'R2', 3000, 80, 469, 235, datetime.date(2015, 1, 1), 'ST356', Decimal('0.6411'), 'apartment', '1', 'Y', 'N', 'New York', 'NY', 11101),
#  ('W57', 'L11495', 'R6', 3900, 116, 361, 284, datetime.date(2015, 1, 2), 'ST357', Decimal('0.5041'), 'apartment', '2', 'Y', 'N', 'New York', 'NY', 11211),
#  ('W58', 'L11495', 'R10', 2800, 102, 799, 355, datetime.date(2015, 1, 1), 'ST358', Decimal('0.4027'), 'house', '1', 'Y', 'N', 'New York', 'NY', 11211),
#  ('W59', 'L11495', 'R14', 3500, 188, 724, 436, datetime.date(2015, 1, 1), 'ST359', Decimal('0.5068'), 'house', '2', 'Y', 'N', 'New York', 'NY', 11211),
#  ('W36', 'L4804', 'R2', 1700, 98, 432, 228, datetime.date(2015, 1, 1), 'ST36', Decimal('0.5205'), 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60654),
#  ('W60', 'L11495', 'R2', 2600, 69, 406, 250, datetime.date(2015, 1, 3), 'ST360', Decimal('0.3699'), 'apartment', '1', 'Y', 'N', 'New York', 'NY', 11211),
#  ('W61', 'L1734', 'R6', 2695, 265, 534, 443, datetime.date(2015, 1, 3), 'ST361', Decimal('0.2356'), 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94025),
#  ('W62', 'L1734', 'R10', 3000, 158, 706, 343, datetime.date(2015, 1, 1), 'ST362', Decimal('0.5808'), 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94025),
#  ('W63', 'L1734', 'R14', 4000, 306, 781, 739, datetime.date(2015, 2, 1), 'ST363', Decimal('0.0192'), 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94025),
#  ('W64', 'L1734', 'R2', 2295, 100, 469, 270, datetime.date(2015, 1, 2), 'ST364', Decimal('0.4685'), 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94025),
#  ('W65', 'L1735', 'R6', 3000, 270, 543, 424, datetime.date(2015, 1, 1), 'ST365', Decimal('0.3425'), 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94301),
#  ('W66', 'L1735', 'R10', 3300, 283, 1261, 980, datetime.date(2015, 1, 1), 'ST366', Decimal('0.2712'), 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94301),
#  ('W37', 'L11419', 'R2', 3000, 87, 512, 337, datetime.date(2015, 1, 1), 'ST37', Decimal('0.4630'), 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10002),
#  ('W38', 'L11419', 'R6', 3200, 154, 480, 154, datetime.date(2015, 1, 4), 'ST38', Decimal('0.6795'), 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10002),
#  ('W39', 'L11421', 'R6', 4500, 273, 853, 432, datetime.date(2015, 1, 1), 'ST39', Decimal('0.6822'), 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10004),
#  ('W4', 'L9531', 'R2', 800, 53, 188, 104, datetime.date(2015, 1, 2), 'ST4', Decimal('0.5699'), 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27514),
#  ('W40', 'L11421', 'R10', 4500, 103, 807, 200, datetime.date(2015, 1, 2), 'ST40', Decimal('0.8685'), 'house', '1', 'Y', 'N', 'New York', 'NY', 10004),
#  ('W41', 'L11421', 'R14', 5500, 200, 770, 428, datetime.date(2015, 1, 1), 'ST41', Decimal('0.5233'), 'house', '2', 'Y', 'N', 'New York', 'NY', 10004),
#  ('W42', 'L11421', 'R2', 3500, 151, 890, 576, datetime.date(2015, 1, 1), 'ST42', Decimal('0.4603'), 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10004),
#  ('W22', 'L4765', 'R10', 2700, 202, 629, 389, datetime.date(2015, 1, 1), 'ST422', Decimal('0.5123'), 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60611),
#  ('W23', 'L4765', 'R14', 3200, 195, 844, 325, datetime.date(2015, 1, 2), 'ST423', Decimal('0.8164'), 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60611),
#  ('W24', 'L4765', 'R2', 1700, 98, 430, 239, datetime.date(2015, 1, 1), 'ST424', Decimal('0.6767'), 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60611),
#  ('W25', 'L4770', 'R2', 1600, 94, 411, 209, datetime.date(2015, 1, 1), 'ST425', Decimal('0.5397'), 'apartment', '1', 'Y', 'N', 'Chicago', 'IL', 60616),
#  ('W26', 'L4770', 'R6', 2100, 130, 438, 265, datetime.date(2015, 1, 1), 'ST426', Decimal('0.4027'), 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60616),
#  ('W27', 'L4770', 'R10', 1200, 162, 504, 435, datetime.date(2015, 1, 3), 'ST427', Decimal('0.4000'), 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60616),
#  ('W28', 'L4770', 'R14', 2100, 175, 755, 487, datetime.date(2015, 1, 9), 'ST428', Decimal('0.4301'), 'house', '2', 'Y', 'N', 'Chicago', 'IL', 60616),
#  ('W29', 'L4794', 'R6', 2500, 129, 431, 231, datetime.date(2015, 1, 5), 'ST429', Decimal('0.4027'), 'apartment', '2', 'Y', 'N', 'Chicago', 'IL', 60642),
#  ('W43', 'L11427', 'R6', 4000, 218, 681, 560, datetime.date(2015, 1, 3), 'ST43', Decimal('0.3534'), 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10014),
#  ('W30', 'L4794', 'R10', 2500, 186, 578, 490, datetime.date(2015, 1, 4), 'ST430', Decimal('0.2301'), 'house', '1', 'Y', 'N', 'Chicago', 'IL', 60642),
#  ('W44', 'L11427', 'R2', 3000, 109, 640, 288, datetime.date(2015, 1, 2), 'ST44', Decimal('0.4986'), 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10014),
#  ('W45', 'L11431', 'R6', 5600, 196, 612, 373, datetime.date(2015, 1, 3), 'ST45', Decimal('0.5151'), 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10019),
#  ('W46', 'L11431', 'R10', 3200, 165, 1296, 420, datetime.date(2015, 1, 1), 'ST46', Decimal('0.8712'), 'house', '1', 'Y', 'N', 'New York', 'NY', 10019),
#  ('W47', 'L11431', 'R14', 3500, 268, 1032, 593, datetime.date(2015, 1, 2), 'ST47', Decimal('0.5068'), 'house', '2', 'Y', 'N', 'New York', 'NY', 10019),
#  ('W48', 'L11431', 'R2', 3400, 106, 624, 436, datetime.date(2015, 1, 1), 'ST48', Decimal('0.2822'), 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10019),
#  ('W188', 'L1882', 'R14', 1900, 227, 861, 568, datetime.date(2015, 1, 8), 'ST488', Decimal('0.1890'), 'house', '2', 'Y', 'N', 'San Diego', 'CA', 91910),
#  ('W189', 'L1883', 'R2', 900, 176, 440, 318, datetime.date(2015, 1, 7), 'ST489', Decimal('0.2904'), 'apartment', '1', 'Y', 'N', 'San Diego', 'CA', 91950),
#  ('W49', 'L11434', 'R6', 4200, 210, 654, 426, datetime.date(2015, 1, 1), 'ST49', Decimal('0.5425'), 'apartment', '2', 'Y', 'N', 'New York', 'NY', 10023),
#  ('W190', 'L1883', 'R6', 1100, 225, 1033, 538, datetime.date(2015, 1, 1), 'ST490', Decimal('0.5808'), 'apartment', '2', 'Y', 'N', 'San Diego', 'CA', 91950),
#  ('W5', 'L9532', 'R6', 1100, 111, 148, 142, datetime.date(2015, 1, 4), 'ST5', Decimal('0.0822'), 'apartment', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27516),
#  ('W50', 'L11434', 'R10', 3000, 133, 1040, 621, datetime.date(2015, 1, 5), 'ST50', Decimal('0.3479'), 'house', '1', 'Y', 'N', 'New York', 'NY', 10023),
#  ('W51', 'L11434', 'R14', 3900, 231, 888, 535, datetime.date(2015, 1, 2), 'ST51', Decimal('0.4767'), 'house', '2', 'Y', 'N', 'New York', 'NY', 10023),
#  ('W212', 'L12260', 'R14', 1480, 175, 310, 249, datetime.date(2015, 1, 1), 'ST512', Decimal('0.4411'), 'house', '2', 'Y', 'N', 'Columbus', 'OH', 43212),
#  ('W213', 'L12264', 'R2', 650, 80, 156, 107, datetime.date(2015, 1, 1), 'ST513', Decimal('0.4795'), 'apartment', '1', 'Y', 'N', 'Columbus', 'OH', 43222),
#  ('W214', 'L12264', 'R6', 920, 108, 205, 147, datetime.date(2015, 1, 1), 'ST514', Decimal('0.4137'), 'apartment', '2', 'Y', 'N', 'Columbus', 'OH', 43222),
#  ('W215', 'L12264', 'R10', 880, 145, 333, 246, datetime.date(2015, 1, 3), 'ST515', Decimal('0.4438'), 'house', '1', 'Y', 'N', 'Columbus', 'OH', 43222),
#  ('W216', 'L12264', 'R14', 1200, 160, 310, 169, datetime.date(2015, 1, 4), 'ST516', Decimal('0.6192'), 'house', '2', 'Y', 'N', 'Columbus', 'OH', 43222),
#  ('W217', 'L16888', 'R2', 1000, 95, 280, 174, datetime.date(2015, 1, 2), 'ST517', Decimal('0.5479'), 'apartment', '1', 'Y', 'N', 'Richmond', 'VA', 23113),
#  ('W233', 'L14416', 'R2', 1165, 135, 220, 180, datetime.date(2015, 1, 2), 'ST519', Decimal('0.3425'), 'apartment', '1', 'Y', 'N', 'Charleston', 'SC', 29438),
#  ('W52', 'L11434', 'R2', 3600, 137, 808, 196, datetime.date(2015, 1, 2), 'ST52', Decimal('0.7781'), 'apartment', '1', 'Y', 'N', 'New York', 'NY', 10023),
#  ('W234', 'L14416', 'R6', 1625, 220, 312, 260, datetime.date(2015, 1, 1), 'ST520', Decimal('0.6000'), 'apartment', '2', 'Y', 'N', 'Charleston', 'SC', 29438),
#  ('W53', 'L11480', 'R6', 3500, 155, 483, 294, datetime.date(2015, 1, 2), 'ST53', Decimal('0.3973'), 'apartment', '2', 'Y', 'N', 'New York', 'NY', 11101),
#  ('W54', 'L11480', 'R10', 2500, 111, 868, 471, datetime.date(2015, 1, 1), 'ST54', Decimal('0.6000'), 'house', '1', 'Y', 'N', 'New York', 'NY', 11101),
#  ('W6', 'L9532', 'R10', 900, 116, 296, 141, datetime.date(2015, 1, 1), 'ST6', Decimal('0.5479'), 'house', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27516),
#  ('W67', 'L1735', 'R14', 4500, 530, 1354, 994, datetime.date(2015, 1, 6), 'ST67', Decimal('0.4301'), 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94301),
#  ('W68', 'L1735', 'R2', 2700, 103, 483, 284, datetime.date(2015, 1, 1), 'ST68', Decimal('0.6055'), 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94301),
#  ('W69', 'L1736', 'R2', 2700, 110, 515, 236, datetime.date(2015, 1, 2), 'ST69', Decimal('0.5671'), 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94303),
#  ('W7', 'L9532', 'R14', 1100, 136, 335, 188, datetime.date(2015, 1, 2), 'ST7', Decimal('0.6192'), 'house', '2', 'Y', 'N', 'Chapel Hill', 'NC', 27516),
#  ('W70', 'L1736', 'R6', 3000, 270, 544, 329, datetime.date(2015, 1, 1), 'ST70', Decimal('0.7041'), 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94303),
#  ('W71', 'L1736', 'R10', 4500, 231, 1027, 549, datetime.date(2015, 1, 1), 'ST71', Decimal('0.4438'), 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94303),
#  ('W72', 'L1736', 'R14', 4900, 379, 969, 652, datetime.date(2015, 1, 2), 'ST72', Decimal('0.4466'), 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94303),
#  ('W73', 'L1737', 'R6', 3300, 264, 532, 378, datetime.date(2015, 1, 1), 'ST73', Decimal('0.4219'), 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94305),
#  ('W74', 'L1737', 'R10', 4500, 151, 673, 255, datetime.date(2015, 1, 1), 'ST74', Decimal('0.5918'), 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94305),
#  ('W75', 'L1737', 'R14', 4200, 278, 711, 441, datetime.date(2015, 1, 1), 'ST75', Decimal('0.5726'), 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94305),
#  ('W76', 'L1737', 'R2', 2500, 98, 460, 356, datetime.date(2015, 1, 1), 'ST76', Decimal('0.4247'), 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94305),
#  ('W77', 'L1738', 'R2', 2500, 108, 507, 437, datetime.date(2015, 1, 4), 'ST77', Decimal('0.0795'), 'apartment', '1', 'Y', 'N', 'Palo Alto', 'CA', 94306),
#  ('W78', 'L1738', 'R6', 3300, 270, 543, 461, datetime.date(2015, 1, 1), 'ST78', Decimal('0.3178'), 'apartment', '2', 'Y', 'N', 'Palo Alto', 'CA', 94306),
#  ('W79', 'L1738', 'R10', 4500, 186, 829, 669, datetime.date(2015, 1, 1), 'ST79', Decimal('0.3123'), 'house', '1', 'Y', 'N', 'Palo Alto', 'CA', 94306),
#  ('W8', 'L9532', 'R2', 500, 50, 174, 121, datetime.date(2015, 1, 2), 'ST8', Decimal('0.3973'), 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27516),
#  ('W80', 'L1738', 'R14', 4200, 319, 815, 437, datetime.date(2015, 1, 1), 'ST80', Decimal('0.6110'), 'house', '2', 'Y', 'N', 'Palo Alto', 'CA', 94306),
#  ('W81', 'L1940', 'R6', 3600, 332, 805, 663, datetime.date(2015, 1, 1), 'ST81', Decimal('0.2329'), 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94103),
#  ('W82', 'L1940', 'R10', 4000, 179, 629, 337, datetime.date(2015, 1, 2), 'ST82', Decimal('0.5068'), 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94103),
#  ('W83', 'L1940', 'R14', 5500, 227, 813, 447, datetime.date(2015, 1, 2), 'ST83', Decimal('0.6164'), 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94103),
#  ('W84', 'L1940', 'R2', 3000, 115, 650, 610, datetime.date(2015, 1, 1), 'ST84', Decimal('0.1014'), 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94103),
#  ('W85', 'L1941', 'R6', 4000, 220, 534, 302, datetime.date(2015, 1, 6), 'ST85', Decimal('0.3151'), 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94110),
#  ('W86', 'L1941', 'R10', 4000, 128, 450, 213, datetime.date(2015, 1, 2), 'ST86', Decimal('0.6521'), 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94110),
#  ('W87', 'L1941', 'R14', 5000, 152, 546, 364, datetime.date(2015, 1, 1), 'ST87', Decimal('0.5123'), 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94110),
#  ('W88', 'L1941', 'R2', 3200, 94, 528, 251, datetime.date(2015, 1, 1), 'ST88', Decimal('0.6274'), 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94110),
#  ('W89', 'L1942', 'R6', 3500, 194, 471, 343, datetime.date(2015, 1, 9), 'ST89', Decimal('0.3973'), 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94112),
#  ('W9', 'L9533', 'R2', 965, 50, 174, 125, datetime.date(2015, 1, 2), 'ST9', Decimal('0.3753'), 'apartment', '1', 'Y', 'N', 'Chapel Hill', 'NC', 27517),
#  ('W90', 'L1942', 'R10', 3200, 138, 485, 251, datetime.date(2015, 1, 1), 'ST90', Decimal('0.3342'), 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94112),
#  ('W91', 'L1942', 'R14', 3500, 152, 547, 404, datetime.date(2015, 1, 1), 'ST91', Decimal('0.3616'), 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94112),
#  ('W92', 'L1942', 'R2', 3000, 77, 432, 161, datetime.date(2015, 1, 9), 'ST92', Decimal('0.2658'), 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94112),
#  ('W93', 'L1943', 'R2', 2600, 100, 565, 408, datetime.date(2015, 1, 4), 'ST93', Decimal('0.3863'), 'apartment', '1', 'Y', 'N', 'San Francisco', 'CA', 94118),
#  ('W94', 'L1943', 'R6', 4000, 204, 494, 284, datetime.date(2015, 1, 1), 'ST94', Decimal('0.3151'), 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94118),
#  ('W95', 'L1943', 'R10', 4000, 257, 903, 443, datetime.date(2015, 1, 2), 'ST95', Decimal('0.5562'), 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94118),
#  ('W96', 'L1943', 'R14', 5100, 256, 916, 718, datetime.date(2015, 1, 1), 'ST96', Decimal('0.4493'), 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94118),
#  ('W97', 'L1944', 'R6', 5600, 265, 644, 478, datetime.date(2015, 1, 5), 'ST97', Decimal('0.3178'), 'apartment', '2', 'Y', 'N', 'San Francisco', 'CA', 94129),
#  ('W98', 'L1944', 'R10', 5000, 236, 829, 533, datetime.date(2015, 1, 1), 'ST98', Decimal('0.5123'), 'house', '1', 'Y', 'N', 'San Francisco', 'CA', 94129),
#  ('W99', 'L1944', 'R14', 6000, 244, 872, 566, datetime.date(2015, 1, 1), 'ST99', Decimal('0.3699'), 'house', '2', 'Y', 'N', 'San Francisco', 'CA', 94129)]

# %% [markdown]
# ### Download the file to excel for further Data Cleaning
#
# Transfer data from jupyter to excel. The Command queries is written below

# %%
Capstone_data=%sql SELECT DISTINCT w.ws_property_id,w.location, w.property_type,w.current_monthly_rent,srp.percentile_10th_price,srp.percentile_90th_price,srp.sample_nightly_rent_price,srd.rental_date,srd.st_property, COUNT(srd.rental_date)/365 AS occupancy_rate,p.apt_house,p.num_bedrooms,p.kitchen,p.shared,l.city,l.state,l.zipcode FROM watershed_property_info w JOIN st_property_info spi ON (w.location=spi.location AND w.property_type=spi.property_type) JOIN st_rental_prices srp ON (spi.location=srp.location AND spi.property_type=srp.property_type) JOIN property_type p ON w.property_type=p.property_type_id JOIN location l ON w.location=l.location_id JOIN st_rental_dates srd ON spi.st_property_id = srd.st_property WHERE YEAR(srd.rental_date)=2015 GROUP BY srd.st_property;
Capstone_data.csv('Capstone_data.csv')
